# %% [markdown]
# # Supervised Topic Modeling with Labeled LDA
#
# In this notebook, we train a **Labeled Latent Dirichlet Allocation (Labeled LDA)** model to learn topics associated with predefined `Category` labels from report view descriptions. This allows us to:
# - Learn label-specific topics from text
# - Predict and interpret categories for new or unlabeled views
# - Improve semantic tagging of report views

# %%
import pandas as pd
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk
import tomotopy as tp

nltk.download('punkt')
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 100)

# Cargar la hoja "Views"
df = pd.read_excel("../raw/Reporting_Inventory.xlsx", sheet_name="Views")
df = df[df["Description"].notna() & df["Category"].notna() & df["Report View"].notna()]
df.head(2)
# Out:
# [nltk_data] Downloading package punkt to /Users/cbadenes/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/cbadenes/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#   ID Data Product           Report Name     Product Owner        PBIX_File  \
# 0       RPPBI0032  Feeder Market - 2024  Jonathan Shields  LifeReport.pbix
# 1       RPPBI0032  Feeder Market - 2024  Jonathan Shields  LifeReport.pbix
#
#                      Report View  \
# 0                       CRITERIA
# 1  DESTINATION_OF_FEEDER_MARKETS
#
#                                                                                                         Description  \
# 0                                                     Methodolody and definition of the algorithim of Feeder Market
# 1  View focused on understand the performance by hotel for a specific feeder market o selection of feeder marktes.
#
#       Category      Status Rename  \
# 0  Informative  Productive    NaN
# 1   Functional  Productive    NaN
#
#                                                      Dimensions  \
# 0                                                           NaN
# 1  Hotel, month, Feeder Market, Segment, Channel Mix, Room Type
#
#                                                                                    KPIs  \
# 0                                                                                   NaN
# 1  Total Revenue, Room Revenue, RN, Lead Time, Lenght of Stay, AOV, ADR, ADR Net, %Cost
#
#   Other Terms Filters Tags    Priority
# 0         NaN     NaN  NaN  Priority 1
# 1         NaN     NaN  NaN  Priority 1

# %%
# Preprocesamiento
def preprocess(text):
    text = text.lower()
    text = re.sub(r"[^a-záéíóúñü\s]", "", text)
    tokens = word_tokenize(text)
    return [t for t in tokens if t not in stop_words]

#df["tokens"] = df["Description"].apply(preprocess)
#df["tokens"] = df["tokens"] + df["Report View"].apply(preprocess)

df["tokens"] = df["Report View"].apply(preprocess)
df["label"] = df["Category"].str.lower().str.strip()
df.head(2)
# Out:
#   ID Data Product           Report Name     Product Owner        PBIX_File  \
# 0       RPPBI0032  Feeder Market - 2024  Jonathan Shields  LifeReport.pbix
# 1       RPPBI0032  Feeder Market - 2024  Jonathan Shields  LifeReport.pbix
#
#                      Report View  \
# 0                       CRITERIA
# 1  DESTINATION_OF_FEEDER_MARKETS
#
#                                                                                                         Description  \
# 0                                                     Methodolody and definition of the algorithim of Feeder Market
# 1  View focused on understand the performance by hotel for a specific feeder market o selection of feeder marktes.
#
#       Category      Status Rename  \
# 0  Informative  Productive    NaN
# 1   Functional  Productive    NaN
#
#                                                      Dimensions  \
# 0                                                           NaN
# 1  Hotel, month, Feeder Market, Segment, Channel Mix, Room Type
#
#                                                                                    KPIs  \
# 0                                                                                   NaN
# 1  Total Revenue, Room Revenue, RN, Lead Time, Lenght of Stay, AOV, ADR, ADR Net, %Cost
#
#   Other Terms Filters Tags    Priority                        tokens  \
# 0         NaN     NaN  NaN  Priority 1                    [criteria]
# 1         NaN     NaN  NaN  Priority 1  [destinationoffeedermarkets]
#
#          label
# 0  informative
# 1   functional

# %%
df["label"].value_counts()
# Out:
# label
# functional      360
# index            67
# executive        57
# informative      42
# self-service     13
# other            12
# master data       7
# Name: count, dtype: int64

# %% [markdown]
# ## Train a labeled LDA
#
# * tw=tp.TermWeight.ONE
# This sets the term weighting scheme to no weighting (i.e., each word has equal importance).
# Alternative values include:
#     * tp.TermWeight.PMI – Pointwise Mutual Information
#     * tp.TermWeight.IDF – Inverse Document Frequency
#     * tp.TermWeight.TFIDF – Term Frequency–Inverse Document Frequency
#
# * min_cf=3
# Minimum collection frequency: a token must appear in at least 3 documents to be included in the vocabulary.
# This filters out extremely rare words to reduce noise.
#
# * rm_top=5
# Removes the top 5 most frequent tokens from the vocabulary.
# These are typically very common terms (e.g. "data", "report") that add little semantic value for topic modeling.

# %%
import tomotopy as tp

# Obtener etiquetas únicas de forma segura
unique_labels = sorted(set(df["label"]))

# Crear modelo Labeled LDA
model = tp.PLDAModel(tw=tp.TermWeight.ONE, min_cf=3, rm_top=5, alpha=0.1, eta=0.01)

# Añadir documentos
for tokens, label in zip(df["tokens"], df["label"]):
    model.add_doc(tokens, labels=[label])

# Entrenar progresivamente
model.train(0)
for i in range(100, 1000, 100):
    model.train(100)
    print(f"Log-likelihood after {i} iterations: {model.ll_per_word:.4f}")
# Out:
# Log-likelihood after 100 iterations: -5.3487
# Log-likelihood after 200 iterations: -5.3486
# Log-likelihood after 300 iterations: -5.3484
# Log-likelihood after 400 iterations: -5.3481
# Log-likelihood after 500 iterations: -5.3485
# Log-likelihood after 600 iterations: -5.3485
# Log-likelihood after 700 iterations: -5.3483
# Log-likelihood after 800 iterations: -5.3482
# Log-likelihood after 900 iterations: -5.3486

# %% [markdown]
# ## Evaluate the Model

# %%
# Ver las palabras más relevantes por categoría
for i, label in enumerate(unique_labels):
    print(f"Top words for label '{label}':")
    print(model.get_topic_words(i, top_n=10))
    print()
# Out:
# Top words for label 'executive':
# [('glossary', 0.48243799805641174), ('information', 0.2069559246301651), ('criteria', 0.13808540999889374), ('compset', 0.06921487301588058), ('info', 0.034779611974954605), ('channel', 0.034779611974954605), ('date', 0.0003443525929469615), ('home', 0.0003443525929469615), ('dashboard', 0.0003443525929469615), ('vs', 0.0003443525929469615)]
#
# Top words for label 'functional':
# [('performance', 0.03713095933198929), ('dashboard', 0.026822529733181), ('hotel', 0.024760844185948372), ('process', 0.022699158638715744), ('vs', 0.022699158638715744), ('date', 0.022699158638715744), ('fc', 0.020637473091483116), ('management', 0.020637473091483116), ('pet', 0.01857578754425049), ('business', 0.01857578754425049)]
#
# Top words for label 'index':
# [('executive', 0.4481392204761505), ('overview', 0.08631978183984756), ('redacted', 0.08631978183984756), ('euam', 0.08631978183984756), ('hotel', 0.06909028440713882), ('overall', 0.034631289541721344), ('ecommerce', 0.034631289541721344), ('cost', 0.034631289541721344), ('channel', 0.017401792109012604), ('forecast', 0.017401792109012604)]
#
# Top words for label 'informative':
# [('home', 0.40605491399765015), ('menu', 0.40605491399765015), ('management', 0.15636704862117767), ('glossary', 0.0003121098561678082), ('hotel', 0.0003121098561678082), ('performance', 0.0003121098561678082), ('date', 0.0003121098561678082), ('executive', 0.0003121098561678082), ('dashboard', 0.0003121098561678082), ('vs', 0.0003121098561678082)]
#
# Top words for label 'master data':
# [('database', 0.27268603444099426), ('browser', 0.1819419264793396), ('databrowser', 0.13656987249851227), ('adhoc', 0.13656987249851227), ('creation', 0.09119781851768494), ('date', 0.09119781851768494), ('pos', 0.0458257682621479), ('home', 0.0004537204804364592), ('dashboard', 0.0004537204804364592), ('vs', 0.0004537204804364592)]
#
# Top words for label 'other':
# [('hotel', 0.49752476811408997), ('oco', 0.25), ('performance', 0.002475247485563159), ('glossary', 0.002475247485563159), ('management', 0.002475247485563159), ('menu', 0.002475247485563159), ('date', 0.002475247485563159), ('home', 0.002475247485563159), ('dashboard', 0.002475247485563159), ('vs', 0.002475247485563159)]
#
# Top words for label 'self-service':
# [('check', 0.49752476811408997), ('alerts', 0.25), ('hotel', 0.002475247485563159), ('glossary', 0.002475247485563159), ('management', 0.002475247485563159), ('menu', 0.002475247485563159), ('date', 0.002475247485563159), ('home', 0.002475247485563159), ('dashboard', 0.002475247485563159), ('vs', 0.002475247485563159)]

# %% [markdown]
# ### Make Inferences

# %%
#tokens = preprocess("The reports sent by STR every 3 months with forecast data from some markets of %OCC, ADR and RevPar, are consolidated on this tab.")
tokens = preprocess("glossary of information by criteria kn a compset")
#doc = model.make_doc(tokens)
doc = model.make_doc(tokens, labels=unique_labels) 
topic_dist, _ = model.infer(doc)
    
# Get most probable label
best_label = max(zip(unique_labels, topic_dist), key=lambda x: x[1])[0]
print("Topic:",best_label)
# Out:
# Topic: executive

# %% [markdown]
# ## Use the model

# %%
# Aplicar a vistas sin categoría
unlabeled_df = pd.read_excel("../raw/Reporting_Inventory.xlsx", sheet_name="Views")
unlabeled_df = unlabeled_df[unlabeled_df["Category"].isna() & unlabeled_df["Description"].notna()]
unlabeled_df["tokens"] = unlabeled_df["Description"].apply(preprocess)

# Predecir la categoría más probable
predictions = []
for tokens in unlabeled_df["tokens"]:
    doc = model.make_doc(tokens)
    topic_dist, _ = model.infer(doc)

    # Buscar la mejor etiqueta usando su probabilidad
    best_label = max(zip(unique_labels, topic_dist), key=lambda x: x[1])[0]
    predictions.append(best_label)

unlabeled_df["predicted_category"] = predictions
unlabeled_df.head(10)
# Out:
#     ID Data Product                    Report Name     Product Owner  \
# 182       RPPBI0034  Corporate Market Share - 2024      Raven Jordan
# 183       RPPBI0034  Corporate Market Share - 2024      Raven Jordan
# 259       RPPBI0150  Corporate Market Share - 2025  Matthew Callahan
# 320       RPPBI0173      Daily Revenue Report 2025        Tasha Hall
# 358       RPPBI0062          Price Competitiveness     Nicole Carter
# 362       RPPBI0062          Price Competitiveness     Nicole Carter
#
#                 PBIX_File                  Report View  \
# 182  CharacterReport.pbix  STR Forecast Dashboard 2024
# 183  CharacterReport.pbix  STR Forecast Dashboard 2025
# 259       SameReport.pbix  STR Forecast Dashboard 2025
# 320      AboutReport.pbix       Pick Up Channel Detail
# 358      AboutReport.pbix             Booking Criteria
# 362      AboutReport.pbix                       Page 1
#
#                                                                                                                                                                                                                          Description  \
# 182                                                                                               The reports sent by STR every 3 months with forecast data from some markets of %OCC, ADR and RevPar, are consolidated on this tab.
# 183                                                                                               The reports sent by STR every 3 months with forecast data from some markets of %OCC, ADR and RevPar, are consolidated on this tab.
# 259                                                                                               The reports sent by STR every 3 months with forecast data from some markets of %OCC, ADR and RevPar, are consolidated on this tab.
# 320                                                                                                                                                                                                                          DELETED
# 358  This view is exclusively for Booking.com,given that they have their offensive criteria. They stablish that a searchis considered offensive when the price difference is greater then 3% and the ranking position is less than 4
# 362                                                                                                                                                                                                                         internal
#
#     Category      Status Rename                                  Dimensions  \
# 182      NaN  Productive    NaN                            Cities available
# 183      NaN  Productive    NaN                            Cities available
# 259      NaN  Productive    NaN                            Cities available
# 320      NaN         NaN    NaN                                         NaN
# 358      NaN  Productive    NaN  BU, Country, City, Hotel, Brand, META, OTA
# 362      NaN    Internal    NaN                                         NaN
#
#                        KPIs           Other Terms  \
# 182  Occupancy, ADR, RevPar  %Chg last 2 forecast
# 183  Occupancy, ADR, RevPar  %Chg last 2 forecast
# 259  Occupancy, ADR, RevPar  %Chg last 2 forecast
# 320                     NaN                   NaN
# 358                     NaN                   NaN
# 362                     NaN                   NaN
#
#                                                                                                                            Filters  \
# 182  Forecast Month, Flag STR is Yes, Hotel_Name is not Hotel Puebla Finsa or Hotel Curitiba The Five or Hotel Lisboa Campo Grande
# 183  Forecast Month, Flag STR is Yes, Hotel_Name is not Hotel Puebla Finsa or Hotel Curitiba The Five or Hotel Lisboa Campo Grande
# 259  Forecast Month, Flag STR is Yes, Hotel_Name is not Hotel Puebla Finsa or Hotel Curitiba The Five or Hotel Lisboa Campo Grande
# 320                                                                                                                            NaN
# 358                                                                                                                            NaN
# 362                                                                                                                            NaN
#
#                                            Tags    Priority  \
# 182  STR Forecast, Corporate Market Share, 2024  Priority 1
# 183  STR Forecast, Corporate Market Share, 2024  Priority 1
# 259        STR Forecast, Corporate Market Share  Priority 1
# 320                                         NaN  Priority 1
# 358                                         NaN  Priority 1
# 362                                         NaN  Priority 1
#
#                                                                                                                                                         tokens  \
# 182                                                          [reports, sent, str, every, months, forecast, data, markets, occ, adr, revpar, consolidated, tab]
# 183                                                          [reports, sent, str, every, months, forecast, data, markets, occ, adr, revpar, consolidated, tab]
# 259                                                          [reports, sent, str, every, months, forecast, data, markets, occ, adr, revpar, consolidated, tab]
# 320                                                                                                                                                  [deleted]
# 358  [view, exclusively, bookingcomgiven, offensive, criteria, stablish, searchis, considered, offensive, price, difference, greater, ranking, position, less]
# 362                                                                                                                                                 [internal]
#
#     predicted_category
# 182         functional
# 183         functional
# 259         functional
# 320         functional
# 358         functional
# 362         functional

# %%
# Predecir la categoría más probable
predictions = []
for tokens in unlabeled_df["tokens"]:
    doc = model.make_doc(tokens)
    topic_dist, _ = model.infer(doc)

    # Buscar la mejor etiqueta usando su probabilidad
    best_label = max(zip(unique_labels, topic_dist), key=lambda x: x[1])[0]
    predictions.append(best_label)

unlabeled_df["predicted_category"] = predictions
unlabeled_df.head(5)
# Out:
#     ID Data Product                    Report Name     Product Owner  \
# 182       RPPBI0034  Corporate Market Share - 2024      Raven Jordan
# 183       RPPBI0034  Corporate Market Share - 2024      Raven Jordan
# 259       RPPBI0150  Corporate Market Share - 2025  Matthew Callahan
# 320       RPPBI0173      Daily Revenue Report 2025        Tasha Hall
# 358       RPPBI0062          Price Competitiveness     Nicole Carter
#
#                 PBIX_File                  Report View  \
# 182  CharacterReport.pbix  STR Forecast Dashboard 2024
# 183  CharacterReport.pbix  STR Forecast Dashboard 2025
# 259       SameReport.pbix  STR Forecast Dashboard 2025
# 320      AboutReport.pbix       Pick Up Channel Detail
# 358      AboutReport.pbix             Booking Criteria
#
#                                            Description Category      Status  \
# 182  The reports sent by STR every 3 months with fo...      NaN  Productive
# 183  The reports sent by STR every 3 months with fo...      NaN  Productive
# 259  The reports sent by STR every 3 months with fo...      NaN  Productive
# 320                                            DELETED      NaN         NaN
# 358  This view is exclusively for Booking.com,given...      NaN  Productive
#
#     Rename                                  Dimensions  \
# 182    NaN                            Cities available
# 183    NaN                            Cities available
# 259    NaN                            Cities available
# 320    NaN                                         NaN
# 358    NaN  BU, Country, City, Hotel, Brand, META, OTA
#
#                        KPIs           Other Terms  \
# 182  Occupancy, ADR, RevPar  %Chg last 2 forecast
# 183  Occupancy, ADR, RevPar  %Chg last 2 forecast
# 259  Occupancy, ADR, RevPar  %Chg last 2 forecast
# 320                     NaN                   NaN
# 358                     NaN                   NaN
#
#                                                Filters  \
# 182  Forecast Month, Flag STR is Yes, Hotel_Name is...
# 183  Forecast Month, Flag STR is Yes, Hotel_Name is...
# 259  Forecast Month, Flag STR is Yes, Hotel_Name is...
# 320                                                NaN
# 358                                                NaN
#
#                                            Tags    Priority  \
# 182  STR Forecast, Corporate Market Share, 2024  Priority 1
# 183  STR Forecast, Corporate Market Share, 2024  Priority 1
# 259        STR Forecast, Corporate Market Share  Priority 1
# 320                                         NaN  Priority 1
# 358                                         NaN  Priority 1
#
#                                                 tokens predicted_category
# 182  [reports, sent, str, every, months, forecast, ...         functional
# 183  [reports, sent, str, every, months, forecast, ...         functional
# 259  [reports, sent, str, every, months, forecast, ...         functional
# 320                                          [deleted]         functional
# 358  [view, exclusively, bookingcomgiven, offensive...         functional
