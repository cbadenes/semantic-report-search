# %% [markdown]
# # Hybrid Search on Business Reports Using Keywords and Descriptions
#
# This notebook demonstrates how to combine sparse (keyword-based) and dense (embedding-based) retrieval to find relevant report views using two different signals:
# - Keywords from the `reports.csv`
# - Descriptions from `Reporting_Inventory.xlsx`
#
# <a href="https://colab.research.google.com/github/cbadenes/semantic-report-search/blob/main/data/analysis/41_hybrid_search_reports.ipynb" target="_parent">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/>
# </a>

# %%
# !pip install -q sentence-transformers scikit-learn pandas
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 77.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 70.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.8 MB/s eta 0:00:00

# %%
# Revisar las primeras filas de la hoja "Views"
raw_inventory_df = pd.read_excel("Reporting_Inventory.xlsx", sheet_name="Views")
raw_inventory_df.head(2)
# Out:
#   ID Data Product           Report Name     Product Owner        PBIX_File  \
# 0       RPPBI0032  Feeder Market - 2024  Jonathan Shields  LifeReport.pbix
# 1       RPPBI0032  Feeder Market - 2024  Jonathan Shields  LifeReport.pbix
#
#                      Report View  \
# 0                       CRITERIA
# 1  DESTINATION_OF_FEEDER_MARKETS
#
#                                          Description     Category      Status  \
# 0  Methodolody and definition of the algorithim o...  Informative  Productive
# 1  View focused on understand the performance by ...   Functional  Productive
#
#   Rename                                         Dimensions  \
# 0    NaN                                                NaN
# 1    NaN  Hotel, month, Feeder Market, Segment, Channel ...
#
#                                                 KPIs Other Terms Filters Tags  \
# 0                                                NaN         NaN     NaN  NaN
# 1  Total Revenue, Room Revenue, RN, Lead Time, Le...         NaN     NaN  NaN
#
#      Priority
# 0  Priority 1
# 1  Priority 1

# %% [markdown]
# Load and Merge Data

# %%
# Load source files
reports_df = pd.read_csv("reports.csv")
inventory_df = pd.read_excel("Reporting_Inventory.xlsx", sheet_name="Views")

# Merge by 'ID Data Product'
merged_df = reports_df.merge(inventory_df, on="ID Data Product", how="left")
merged_df = merged_df.rename(columns={"Report View_x": "Report View"})
merged_df = merged_df.drop(columns=["Report View_y"])
merged_df = merged_df.rename(columns={"Report Name_x": "Report Name"})
merged_df = merged_df.drop(columns=["Report Name_y"])
merged_df = merged_df.rename(columns={"Tags_x": "Tags"})
merged_df = merged_df.drop(columns=["Tags_y"])



# Clean fields
merged_df["keywords"] = merged_df["keywords"].fillna("")
merged_df["Description"] = merged_df["Description"].fillna("")
merged_df.head(2)
# Out:
#   ID Data Product           Report Name Report View Tags  \
# 0       RPPBI0032  Feeder Market - 2024    CRITERIA  NaN
# 1       RPPBI0032  Feeder Market - 2024    CRITERIA  NaN
#
#                                             keywords     Product Owner  \
# 0  2024, criterion, definition, feed, feeder mark...  Jonathan Shields
# 1  2024, criterion, definition, feed, feeder mark...  Jonathan Shields
#
#          PBIX_File                                        Description  \
# 0  LifeReport.pbix  Methodolody and definition of the algorithim o...
# 1  LifeReport.pbix  View focused on understand the performance by ...
#
#       Category      Status Rename  \
# 0  Informative  Productive    NaN
# 1   Functional  Productive    NaN
#
#                                           Dimensions  \
# 0                                                NaN
# 1  Hotel, month, Feeder Market, Segment, Channel ...
#
#                                                 KPIs Other Terms Filters  \
# 0                                                NaN         NaN     NaN
# 1  Total Revenue, Room Revenue, RN, Lead Time, Le...         NaN     NaN
#
#      Priority
# 0  Priority 1
# 1  Priority 1

# %% [markdown]
# Prepare Sparse Representations (TF-IDF)

# %%
tfidf = TfidfVectorizer()
sparse_matrix = tfidf.fit_transform(merged_df["keywords"])

# %% [markdown]
# Prepare Dense Representations (Embeddings)

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
dense_matrix = model.encode(merged_df["Description"], convert_to_tensor=False)

# %% [markdown]
# Define Hybrid Search Function

# %%
def hybrid_search(query, alpha=0.5, top_k=5):
    # Sparse vector
    sparse_query = tfidf.transform([query])
    sparse_scores = cosine_similarity(sparse_query, sparse_matrix).flatten()

    # Dense vector
    dense_query = model.encode([query])[0]
    dense_scores = cosine_similarity([dense_query], dense_matrix).flatten()

    # Combine scores
    hybrid_scores = alpha * sparse_scores + (1 - alpha) * dense_scores

    # Get top indices and scores
    top_indices = np.argsort(hybrid_scores)[::-1][:top_k]
    top_scores = hybrid_scores[top_indices]

    # Build result DataFrame
    results = merged_df.iloc[top_indices].copy()
    results["score"] = top_scores

    return results[["Report View", "keywords", "Description", "score"]]

# %% [markdown]
# Try It Out!

# %%
hybrid_search("market performance in European destinations")
# Out:
#                       Report View  \
# 14297    C4C_Qualification_Detail
# 14299  Key Potential Destinations
# 25                 EXECUTIVE VIEW
# 106                EXECUTIVE VIEW
# 7                        CRITERIA
#
#                                                 keywords  \
# 14297  account, account handler, account segmentation...
# 14299  account (business travel, analyze, business tr...
# 25     2024, adr, aov, compare, executive, feeder, fe...
# 106    2025, adr, aov, compare, executive, feeder, fe...
# 7      2024, criterion, definition, feed, feeder mark...
#
#                                              Description     score
# 14297  View to analyze Key Potential Destinations by ...  0.436338
# 14299  View to analyze Key Potential Destinations by ...  0.376120
# 25     Benchmark by Destination. Outside information ...  0.358329
# 106    Benchmark by Destination. Outside information ...  0.358171
# 7      Benchmark by Destination. Outside information ...  0.350058

# %%
hybrid_search("staff efficiency and complaints resolution", alpha=0.3)
# Out:
#             Report View                                           keywords  \
# 15304   Home Management  2024, commercial, efficiency, home, index page...
# 5683               HOME  commercial, efficiency, home, index page, inte...
# 5701    Home Management  commercial, efficiency, home, index page, inte...
# 15312   Management View  2024, commercial, commercial team, comparison,...
# 5899   Summary 24 vs 25  commercial, efficiency, hide, hide view, lead,...
#
#                                              Description     score
# 15304  Older version of the report that was launched ...  0.370792
# 5683   View to measure commercial teams efficiency th...  0.363479
# 5701   View to measure commercial teams efficiency th...  0.360196
# 15312  Older version of the report that was launched ...  0.350581
# 5899   View to measure commercial teams efficiency th...  0.347962
