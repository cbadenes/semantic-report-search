# %% [markdown]
# # Zero-Shot Category Inference for Report Views
#
# This notebook uses a transformer-based model from HuggingFace to **infer the most likely category** of a report view based on its textual description, without requiring prior training.
# We use **zero-shot classification** via a model like `facebook/bart-large-mnli`.
#
# Target categories:
# - functional
# - index
# - executive
# - informative
# - self-service
# - other
# - master data
#
#
# <a href="https://colab.research.google.com/github/cbadenes/semantic-report-search/blob/main/data/analysis/31_zeroshot_classification.ipynb" target="_parent">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/>
# </a>

# %%
#!pip install -q transformers

from transformers import pipeline
import pandas as pd

pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 100)

# Load the zero-shot classifier pipeline
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")
# Out:
# Device set to use cpu

# %%
def infer_category(input_text, labels, multi_label=False):
    result = classifier(input_text, labels, multi_label=multi_label)
    return result["labels"][0]  # top predicted category

my_text = "The government is planning to increase taxes on imported goods to support local industries."
my_labels = ["Politics", "Economics", "Entertainment", "Sports"]
print(infer_category(input_text=my_text,labels=my_labels))
# Out:
# Politics

# %%
# Load Excel file with report views
df = pd.read_excel("Reporting_Inventory.xlsx", sheet_name="Views")

# Ensure descriptions are strings
df["Description"] = df["Description"].astype(str)

# Define candidate labels (categories)
candidate_labels = [
    "functional", "index", "executive", "informative", "self-service", "other", "master data"
]

# Filter views with no assigned category
df_unlabeled = df[
    df["Category"].isna() &
    df["Description"].notna() &
    (df["Description"].str.strip() != "") &
    (df["Description"].str.lower().str.strip() != "nan")
]

df_unlabeled.head(10)
# Out:
#     ID Data Product                    Report Name     Product Owner  \
# 182       RPPBI0034  Corporate Market Share - 2024      Raven Jordan
# 183       RPPBI0034  Corporate Market Share - 2024      Raven Jordan
# 259       RPPBI0150  Corporate Market Share - 2025  Matthew Callahan
# 320       RPPBI0173      Daily Revenue Report 2025        Tasha Hall
# 358       RPPBI0062          Price Competitiveness     Nicole Carter
# 362       RPPBI0062          Price Competitiveness     Nicole Carter
#
#                 PBIX_File                  Report View  \
# 182  CharacterReport.pbix  STR Forecast Dashboard 2024
# 183  CharacterReport.pbix  STR Forecast Dashboard 2025
# 259       SameReport.pbix  STR Forecast Dashboard 2025
# 320      AboutReport.pbix       Pick Up Channel Detail
# 358      AboutReport.pbix             Booking Criteria
# 362      AboutReport.pbix                       Page 1
#
#                                                                                                                                                                                                                          Description  \
# 182                                                                                               The reports sent by STR every 3 months with forecast data from some markets of %OCC, ADR and RevPar, are consolidated on this tab.
# 183                                                                                               The reports sent by STR every 3 months with forecast data from some markets of %OCC, ADR and RevPar, are consolidated on this tab.
# 259                                                                                               The reports sent by STR every 3 months with forecast data from some markets of %OCC, ADR and RevPar, are consolidated on this tab.
# 320                                                                                                                                                                                                                          DELETED
# 358  This view is exclusively for Booking.com,given that they have their offensive criteria. They stablish that a searchis considered offensive when the price difference is greater then 3% and the ranking position is less than 4
# 362                                                                                                                                                                                                                         internal
#
#     Category      Status Rename                                  Dimensions  \
# 182      NaN  Productive    NaN                            Cities available
# 183      NaN  Productive    NaN                            Cities available
# 259      NaN  Productive    NaN                            Cities available
# 320      NaN         NaN    NaN                                         NaN
# 358      NaN  Productive    NaN  BU, Country, City, Hotel, Brand, META, OTA
# 362      NaN    Internal    NaN                                         NaN
#
#                        KPIs           Other Terms  \
# 182  Occupancy, ADR, RevPar  %Chg last 2 forecast
# 183  Occupancy, ADR, RevPar  %Chg last 2 forecast
# 259  Occupancy, ADR, RevPar  %Chg last 2 forecast
# 320                     NaN                   NaN
# 358                     NaN                   NaN
# 362                     NaN                   NaN
#
#                                                                                                                            Filters  \
# 182  Forecast Month, Flag STR is Yes, Hotel_Name is not Hotel Puebla Finsa or Hotel Curitiba The Five or Hotel Lisboa Campo Grande
# 183  Forecast Month, Flag STR is Yes, Hotel_Name is not Hotel Puebla Finsa or Hotel Curitiba The Five or Hotel Lisboa Campo Grande
# 259  Forecast Month, Flag STR is Yes, Hotel_Name is not Hotel Puebla Finsa or Hotel Curitiba The Five or Hotel Lisboa Campo Grande
# 320                                                                                                                            NaN
# 358                                                                                                                            NaN
# 362                                                                                                                            NaN
#
#                                            Tags    Priority
# 182  STR Forecast, Corporate Market Share, 2024  Priority 1
# 183  STR Forecast, Corporate Market Share, 2024  Priority 1
# 259        STR Forecast, Corporate Market Share  Priority 1
# 320                                         NaN  Priority 1
# 358                                         NaN  Priority 1
# 362                                         NaN  Priority 1

# %%
# Apply zero-shot classification using lambda to pass extra arguments
df_unlabeled["Predicted Category"] = df_unlabeled["Description"].apply(
    lambda desc: infer_category(desc, candidate_labels, multi_label=False)
)

# Show results
df_unlabeled[["Report View", "Description", "Predicted Category"]].head(20)
# Out:
# <ipython-input-25-1562567997>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unlabeled["Predicted Category"] = df_unlabeled["Description"].apply(
#                      Report View  \
# 182  STR Forecast Dashboard 2024
# 183  STR Forecast Dashboard 2025
# 259  STR Forecast Dashboard 2025
# 320       Pick Up Channel Detail
# 358             Booking Criteria
# 362                       Page 1
#
#                                                                                                                                                                                                                          Description  \
# 182                                                                                               The reports sent by STR every 3 months with forecast data from some markets of %OCC, ADR and RevPar, are consolidated on this tab.
# 183                                                                                               The reports sent by STR every 3 months with forecast data from some markets of %OCC, ADR and RevPar, are consolidated on this tab.
# 259                                                                                               The reports sent by STR every 3 months with forecast data from some markets of %OCC, ADR and RevPar, are consolidated on this tab.
# 320                                                                                                                                                                                                                          DELETED
# 358  This view is exclusively for Booking.com,given that they have their offensive criteria. They stablish that a searchis considered offensive when the price difference is greater then 3% and the ranking position is less than 4
# 362                                                                                                                                                                                                                         internal
#
#     Predicted Category
# 182         functional
# 183         functional
# 259         functional
# 320              other
# 358          executive
# 362              other

# %%
# Save Results
df_unlabeled_sample.to_csv("views_with_predicted_categories_zeroshot.csv", index=False)

# %% [markdown]
# # 2. Extend candidates

# %%
# Construir el texto concatenando campos relevantes
df["TextToClassify"] = (
    df["Report View"].fillna("").astype(str).str.strip() + " - " +
    df["Report Name"].fillna("").astype(str).str.strip() + " - " +
    df["Description"].fillna("").astype(str).str.strip()
)

df_extended_sample = df.head(10).copy()

df_extended_sample.head(10)
# Out:
#   ID Data Product           Report Name     Product Owner           PBIX_File  \
# 0       RPPBI0032  Feeder Market - 2024  Jonathan Shields     LifeReport.pbix
# 1       RPPBI0032  Feeder Market - 2024  Jonathan Shields     LifeReport.pbix
# 2       RPPBI0032  Feeder Market - 2024  Jonathan Shields     LifeReport.pbix
# 3       RPPBI0032  Feeder Market - 2024  Jonathan Shields     LifeReport.pbix
# 4       RPPBI0032  Feeder Market - 2024  Jonathan Shields     LifeReport.pbix
# 5       RPPBI0032  Feeder Market - 2024  Jonathan Shields     LifeReport.pbix
# 6       RPPBI0032  Feeder Market - 2024  Jonathan Shields     LifeReport.pbix
# 7       RPPBI0032  Feeder Market - 2024  Jonathan Shields     LifeReport.pbix
# 8       RPPBI0032  Feeder Market - 2024  Jonathan Shields     LifeReport.pbix
# 9       RPPBI0154  Feeder Market - 2025  Jonathan Shields  OfficerReport.pbix
#
#                      Report View  \
# 0                       CRITERIA
# 1  DESTINATION_OF_FEEDER_MARKETS
# 2                 EXECUTIVE VIEW
# 3            FEEDER MARKET FLOWS
# 4           FEEDER_MARKET_DETAIL
# 5  FEEDER_MARKETS_OF_DESTINATION
# 6                           MENU
# 7             OE MARKET INSIGHTS
# 8              TARGETS FOLLOW UP
# 9                       CRITERIA
#
#                                                                                                                                                                                                                                                                                                               Description  \
# 0                                                                                                                                                                                                                                                           Methodolody and definition of the algorithim of Feeder Market
# 1                                                                                                                                                                                                        View focused on understand the performance by hotel for a specific feeder market o selection of feeder marktes.
# 2                                                                                                                                                                                        Global view to understand Feeder Market Performance compared to previous years diferentiating between domestic and international
# 3  View focused on understanding the booking behaviour by Feeder Market. It allows to understand when, where and through which channels and segments are producing the different feeder markets for a selected booking period. Besides, it shows the flow (Feeder Market to Destination) by contribution of total revenue
# 4                                                                                                                                                                               Detail view of Feeder Markets by Destination including more indepth view by channel, and including Top_Agency and Top_Company information
# 5                                                                                                                                                                                                                                    VIew focused on understanding the feeder markets producing at a specific Destination
# 6                                                                                                                                                                                                                                                                     Index page with interactive buttons to other views.
# 7                                                                                                                                                                                                       Benchmark by Destination. Outside information is provided by Oxford Economics providing a summary developed by AI
# 8                                                                                                                                                                                          View that provides performance vs budget at a feeder Market level. It allows to drill down by destination, segment and channel
# 9                                                                                                                                                                                                                                                           Methodolody and definition of the algorithim of Feeder Market
#
#       Category      Status Rename  \
# 0  Informative  Productive    NaN
# 1   Functional  Productive    NaN
# 2    Executive  Productive    NaN
# 3   Functional  Productive    NaN
# 4   Functional  Productive    NaN
# 5   Functional  Productive    NaN
# 6        Index  Productive    NaN
# 7   Functional  Productive    NaN
# 8   Functional  Productive    NaN
# 9  Informative  Productive    NaN
#
#                                                                                    Dimensions  \
# 0                                                                                         NaN
# 1                                Hotel, month, Feeder Market, Segment, Channel Mix, Room Type
# 2                                Hotel, month, Feeder Market, Segment, Channel Mix, Room Type
# 3  Hotel, month, Feeder Market, Segment, Channel Mix, Room Type, Booked Year and Booked month
# 4                                Hotel, month, Feeder Market, Segment, Channel Mix, Room Type
# 5                                Hotel, month, Feeder Market, Segment, Channel Mix, Room Type
# 6                                                                                         NaN
# 7                                                                               Country, City
# 8                                           Hotel, month, Feeder Market, Segment, Channel Mix
# 9                                Hotel, month, Feeder Market, Segment, Channel Mix, Room Type
#
#                                                                                    KPIs  \
# 0                                                                                   NaN
# 1  Total Revenue, Room Revenue, RN, Lead Time, Lenght of Stay, AOV, ADR, ADR Net, %Cost
# 2  Total Revenue, Room Revenue, RN, Lead Time, Lenght of Stay, AOV, ADR, ADR Net, %Cost
# 3  Total Revenue, Room Revenue, RN, Lead Time, Lenght of Stay, AOV, ADR, ADR Net, %Cost
# 4  Total Revenue, Room Revenue, RN, Lead Time, Lenght of Stay, AOV, ADR, ADR Net, %Cost
# 5  Total Revenue, Room Revenue, RN, Lead Time, Lenght of Stay, AOV, ADR, ADR Net, %Cost
# 6                                                                                   NaN
# 7                                     Total Spending, Total Revenue, Arrivals, Nights,
# 8                                                   Total Revenue, Room Revenue, RN,ADR
# 9  Total Revenue, Room Revenue, RN, Lead Time, Lenght of Stay, AOV, ADR, ADR Net, %Cost
#
#          Other Terms Filters Tags    Priority  \
# 0                NaN     NaN  NaN  Priority 1
# 1                NaN     NaN  NaN  Priority 1
# 2                NaN     NaN  NaN  Priority 1
# 3                NaN     NaN  NaN  Priority 1
# 4                NaN     NaN  NaN  Priority 1
# 5                NaN     NaN  NaN  Priority 1
# 6                NaN     NaN  NaN  Priority 1
# 7  Outbound, Inbound     NaN  NaN  Priority 1
# 8             Budget     NaN  NaN  Priority 1
# 9                NaN     NaN  NaN  Priority 1
#
#                                                                                                                                                                                                                                                                                                                                                         TextToClassify
# 0                                                                                                                                                                                                                                                                      CRITERIA - Feeder Market - 2024 - Methodolody and definition of the algorithim of Feeder Market
# 1                                                                                                                                                                                               DESTINATION_OF_FEEDER_MARKETS - Feeder Market - 2024 - View focused on understand the performance by hotel for a specific feeder market o selection of feeder marktes.
# 2                                                                                                                                                                                             EXECUTIVE VIEW - Feeder Market - 2024 - Global view to understand Feeder Market Performance compared to previous years diferentiating between domestic and international
# 3  FEEDER MARKET FLOWS - Feeder Market - 2024 - View focused on understanding the booking behaviour by Feeder Market. It allows to understand when, where and through which channels and segments are producing the different feeder markets for a selected booking period. Besides, it shows the flow (Feeder Market to Destination) by contribution of total revenue
# 4                                                                                                                                                                              FEEDER_MARKET_DETAIL - Feeder Market - 2024 - Detail view of Feeder Markets by Destination including more indepth view by channel, and including Top_Agency and Top_Company information
# 5                                                                                                                                                                                                                          FEEDER_MARKETS_OF_DESTINATION - Feeder Market - 2024 - VIew focused on understanding the feeder markets producing at a specific Destination
# 6                                                                                                                                                                                                                                                                                    MENU - Feeder Market - 2024 - Index page with interactive buttons to other views.
# 7                                                                                                                                                                                                        OE MARKET INSIGHTS - Feeder Market - 2024 - Benchmark by Destination. Outside information is provided by Oxford Economics providing a summary developed by AI
# 8                                                                                                                                                                                            TARGETS FOLLOW UP - Feeder Market - 2024 - View that provides performance vs budget at a feeder Market level. It allows to drill down by destination, segment and channel
# 9                                                                                                                                                                                                                                                                      CRITERIA - Feeder Market - 2025 - Methodolody and definition of the algorithim of Feeder Market

# %%
# Aplicar clasificación usando el nuevo texto combinado
df_extended_sample["Predicted Category"] = df_extended_sample["TextToClassify"].apply(
    lambda text: infer_category(text, candidate_labels, multi_label=False)
)

# Show results
df_extended_sample[["Report View", "Description", "Category", "Predicted Category"]].head(20)
# Out:
#                      Report View  \
# 0                       CRITERIA
# 1  DESTINATION_OF_FEEDER_MARKETS
# 2                 EXECUTIVE VIEW
# 3            FEEDER MARKET FLOWS
# 4           FEEDER_MARKET_DETAIL
# 5  FEEDER_MARKETS_OF_DESTINATION
# 6                           MENU
# 7             OE MARKET INSIGHTS
# 8              TARGETS FOLLOW UP
# 9                       CRITERIA
#
#                                                                                                                                                                                                                                                                                                               Description  \
# 0                                                                                                                                                                                                                                                           Methodolody and definition of the algorithim of Feeder Market
# 1                                                                                                                                                                                                        View focused on understand the performance by hotel for a specific feeder market o selection of feeder marktes.
# 2                                                                                                                                                                                        Global view to understand Feeder Market Performance compared to previous years diferentiating between domestic and international
# 3  View focused on understanding the booking behaviour by Feeder Market. It allows to understand when, where and through which channels and segments are producing the different feeder markets for a selected booking period. Besides, it shows the flow (Feeder Market to Destination) by contribution of total revenue
# 4                                                                                                                                                                               Detail view of Feeder Markets by Destination including more indepth view by channel, and including Top_Agency and Top_Company information
# 5                                                                                                                                                                                                                                    VIew focused on understanding the feeder markets producing at a specific Destination
# 6                                                                                                                                                                                                                                                                     Index page with interactive buttons to other views.
# 7                                                                                                                                                                                                       Benchmark by Destination. Outside information is provided by Oxford Economics providing a summary developed by AI
# 8                                                                                                                                                                                          View that provides performance vs budget at a feeder Market level. It allows to drill down by destination, segment and channel
# 9                                                                                                                                                                                                                                                           Methodolody and definition of the algorithim of Feeder Market
#
#       Category Predicted Category
# 0  Informative        informative
# 1   Functional        informative
# 2    Executive          executive
# 3   Functional         functional
# 4   Functional        informative
# 5   Functional        informative
# 6        Index              index
# 7   Functional              other
# 8   Functional         functional
# 9  Informative        informative
