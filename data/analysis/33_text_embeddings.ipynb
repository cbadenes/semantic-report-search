# %% [markdown]
# # Semantic Search on Report Views Using Transformers
#
# In this notebook, we will:
# - Extract report view descriptions from a CSV file.
# - Encode them into dense vector representations using a pre-trained Transformer model.
# - Implement a semantic search function that finds the most similar report view to a given user query using cosine similarity.
#
# <a href="https://colab.research.google.com/github/cbadenes/semantic-report-search/blob/main/data/analysis/33_text_embeddings.ipynb" target="_parent">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/>
# </a>

# %%
# !pip install -q sentence-transformers

import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 75.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 58.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 35.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 104.6 MB/s eta 0:00:00

# %% [markdown]
# Load Report Data

# %%
df = pd.read_csv('reports.csv')
#df = df[['Report View', 'keywords']].dropna()
df = df.dropna()
df.head()
# Out:
#    ID Data Product            Report Name  \
# 39       RPPBI0004  eCommerce Report 2024
# 42       RPPBI0004  eCommerce Report 2024
# 43       RPPBI0004  eCommerce Report 2024
# 44       RPPBI0004  eCommerce Report 2024
# 45       RPPBI0004  eCommerce Report 2024
#
#                                      Report View                    Tags  \
# 39                            B2B Digital Report             B2B Digital
# 42   Digital By Creation Date Performance Report    Performance, Digital
# 43               Digital Performance (Stay Date)    Performance, Digital
# 44  Ecommerce Performance (Creation Date) Report  Performance, eCommerce
# 45                              Executive Report     Budget, Performance
#
#                                              keywords
# 39  2024, agency, allow, analyze, b2b, b2b digital...
# 42  2024, analytic, brand, channel analytic, count...
# 43  2024, analytic, brand, channel analytic, count...
# 44  2024, analytic, brand, channel analytic, count...
# 45  2024, adr, budget, comparison, contain, creati...

# %% [markdown]
# Generate embeddings

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')  # Lightweight and fast

# Combine 'Report View' and 'keywords' for better context
df['description'] = df['Report View'] + ' - ' + df['keywords']
df['embedding'] = df['description'].apply(lambda x: model.encode(x, convert_to_tensor=True))
df.head(2)
# Out:
#    ID Data Product            Report Name  \
# 39       RPPBI0004  eCommerce Report 2024
# 42       RPPBI0004  eCommerce Report 2024
#
#                                     Report View                  Tags  \
# 39                           B2B Digital Report           B2B Digital
# 42  Digital By Creation Date Performance Report  Performance, Digital
#
#                                              keywords  \
# 39  2024, agency, allow, analyze, b2b, b2b digital...
# 42  2024, analytic, brand, channel analytic, count...
#
#                                           description  \
# 39  B2B Digital Report - 2024, agency, allow, anal...
# 42  Digital By Creation Date Performance Report - ...
#
#                                             embedding
# 39  [tensor(0.0428, device='cuda:0'), tensor(-0.04...
# 42  [tensor(0.0175, device='cuda:0'), tensor(-0.05...

# %% [markdown]
# Semantic Search Function:

# %%
def search_similar_view(query, top_k=4):
    query_vec = model.encode(query, convert_to_tensor=True)
    # Convert embeddings to CPU numpy arrays
    embeddings_np = [emb.cpu().numpy() for emb in df['embedding']]
    query_vec_np = query_vec.cpu().numpy().reshape(1, -1)

    similarities = cosine_similarity(query_vec_np, embeddings_np)
    top_k_idx = np.argsort(similarities[0])[::-1][:top_k]
    return df.iloc[top_k_idx][['Report Name', 'Report View', 'description']]

# %% [markdown]
# Example Queries

# %%
search_similar_view("detailed flow of feeder markets")
# Out:
#                Report Name         Report View  \
# 935  eCommerce Report 2023  Performance Report
# 927  eCommerce Report 2022  Performance Report
# 51   eCommerce Report 2024  Performance Report
# 67   eCommerce Report 2025  Performance Report
#
#                                            description
# 935  Performance Report - 2023, analytic, brand, ch...
# 927  Performance Report - 2022, analytic, brand, ch...
# 51   Performance Report - 2024, analytic, brand, ch...
# 67   Performance Report - 2025, analytic, brand, ch...

# %%
search_similar_view("summary statistics for executives")
# Out:
#                 Report Name        Report View  \
# 213         Cvent Dashboard  Executive Summary
# 60    eCommerce Report 2025   Executive Report
# 45    eCommerce Report 2024   Executive Report
# 242  Hotel Benchmark Report  Executive Summary
#
#                                            description
# 213  Executive Summary - 2025, ad-hoc table, analyz...
# 60   Executive Report - 2025, adr, budget, comparis...
# 45   Executive Report - 2024, adr, budget, comparis...
# 242  Executive Summary - (eft, actuals, analyze, be...

# %%
search_similar_view("market destination performance analysis")
# Out:
#                Report Name         Report View  \
# 51   eCommerce Report 2024  Performance Report
# 927  eCommerce Report 2022  Performance Report
# 67   eCommerce Report 2025  Performance Report
# 935  eCommerce Report 2023  Performance Report
#
#                                            description
# 51   Performance Report - 2024, analytic, brand, ch...
# 927  Performance Report - 2022, analytic, brand, ch...
# 67   Performance Report - 2025, analytic, brand, ch...
# 935  Performance Report - 2023, analytic, brand, ch...
