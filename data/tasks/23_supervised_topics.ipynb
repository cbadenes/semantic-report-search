# %% [markdown]
# ## Prepare Data

# %%
import pandas as pd
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk
import tomotopy as tp

nltk.download('punkt')
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# Cargar la hoja "Views"
df = pd.read_excel("../raw/Reporting_Inventory.xlsx", sheet_name="Views")
df = df[df["Description"].notna() & df["Category"].notna()]

# Preprocesamiento
def preprocess(text):
    text = text.lower()
    text = re.sub(r"[^a-záéíóúñü\s]", "", text)
    tokens = word_tokenize(text)
    return [t for t in tokens if t not in stop_words]

df["tokens"] = df["Description"].apply(preprocess)
df["label"] = df["Category"].str.lower().str.strip()
df.head(10)
# Out:
# [nltk_data] Downloading package punkt to /Users/cbadenes/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/cbadenes/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#   ID Data Product           Report Name     Product Owner           PBIX_File  \
# 0       RPPBI0032  Feeder Market - 2024  Jonathan Shields     LifeReport.pbix
# 1       RPPBI0032  Feeder Market - 2024  Jonathan Shields     LifeReport.pbix
# 2       RPPBI0032  Feeder Market - 2024  Jonathan Shields     LifeReport.pbix
# 3       RPPBI0032  Feeder Market - 2024  Jonathan Shields     LifeReport.pbix
# 4       RPPBI0032  Feeder Market - 2024  Jonathan Shields     LifeReport.pbix
# 5       RPPBI0032  Feeder Market - 2024  Jonathan Shields     LifeReport.pbix
# 6       RPPBI0032  Feeder Market - 2024  Jonathan Shields     LifeReport.pbix
# 7       RPPBI0032  Feeder Market - 2024  Jonathan Shields     LifeReport.pbix
# 8       RPPBI0032  Feeder Market - 2024  Jonathan Shields     LifeReport.pbix
# 9       RPPBI0154  Feeder Market - 2025  Jonathan Shields  OfficerReport.pbix
#
#                      Report View  \
# 0                       CRITERIA
# 1  DESTINATION_OF_FEEDER_MARKETS
# 2                 EXECUTIVE VIEW
# 3            FEEDER MARKET FLOWS
# 4           FEEDER_MARKET_DETAIL
# 5  FEEDER_MARKETS_OF_DESTINATION
# 6                           MENU
# 7             OE MARKET INSIGHTS
# 8              TARGETS FOLLOW UP
# 9                       CRITERIA
#
#                                          Description     Category      Status  \
# 0  Methodolody and definition of the algorithim o...  Informative  Productive
# 1  View focused on understand the performance by ...   Functional  Productive
# 2  Global view to understand Feeder Market Perfor...    Executive  Productive
# 3  View focused on understanding the booking beha...   Functional  Productive
# 4  Detail view of Feeder Markets by Destination i...   Functional  Productive
# 5  VIew focused on understanding the feeder marke...   Functional  Productive
# 6  Index page with interactive buttons to other v...        Index  Productive
# 7  Benchmark by Destination. Outside information ...   Functional  Productive
# 8  View that provides performance vs budget at a ...   Functional  Productive
# 9  Methodolody and definition of the algorithim o...  Informative  Productive
#
#   Rename                                         Dimensions  \
# 0    NaN                                                NaN
# 1    NaN  Hotel, month, Feeder Market, Segment, Channel ...
# 2    NaN  Hotel, month, Feeder Market, Segment, Channel ...
# 3    NaN  Hotel, month, Feeder Market, Segment, Channel ...
# 4    NaN  Hotel, month, Feeder Market, Segment, Channel ...
# 5    NaN  Hotel, month, Feeder Market, Segment, Channel ...
# 6    NaN                                                NaN
# 7    NaN                                      Country, City
# 8    NaN  Hotel, month, Feeder Market, Segment, Channel Mix
# 9    NaN  Hotel, month, Feeder Market, Segment, Channel ...
#
#                                                 KPIs        Other Terms  \
# 0                                                NaN                NaN
# 1  Total Revenue, Room Revenue, RN, Lead Time, Le...                NaN
# 2  Total Revenue, Room Revenue, RN, Lead Time, Le...                NaN
# 3  Total Revenue, Room Revenue, RN, Lead Time, Le...                NaN
# 4  Total Revenue, Room Revenue, RN, Lead Time, Le...                NaN
# 5  Total Revenue, Room Revenue, RN, Lead Time, Le...                NaN
# 6                                                NaN                NaN
# 7  Total Spending, Total Revenue, Arrivals, Nights,   Outbound, Inbound
# 8                Total Revenue, Room Revenue, RN,ADR             Budget
# 9  Total Revenue, Room Revenue, RN, Lead Time, Le...                NaN
#
#   Filters Tags    Priority                                             tokens  \
# 0     NaN  NaN  Priority 1  [methodolody, definition, algorithim, feeder, ...
# 1     NaN  NaN  Priority 1  [view, focused, understand, performance, hotel...
# 2     NaN  NaN  Priority 1  [global, view, understand, feeder, market, per...
# 3     NaN  NaN  Priority 1  [view, focused, understanding, booking, behavi...
# 4     NaN  NaN  Priority 1  [detail, view, feeder, markets, destination, i...
# 5     NaN  NaN  Priority 1  [view, focused, understanding, feeder, markets...
# 6     NaN  NaN  Priority 1         [index, page, interactive, buttons, views]
# 7     NaN  NaN  Priority 1  [benchmark, destination, outside, information,...
# 8     NaN  NaN  Priority 1  [view, provides, performance, vs, budget, feed...
# 9     NaN  NaN  Priority 1  [methodolody, definition, algorithim, feeder, ...
#
#          label
# 0  informative
# 1   functional
# 2    executive
# 3   functional
# 4   functional
# 5   functional
# 6        index
# 7   functional
# 8   functional
# 9  informative

# %%
df["label"].value_counts()
# Out:
# label
# functional      360
# index            67
# executive        57
# informative      42
# self-service     13
# other            12
# master data       7
# Name: count, dtype: int64

# %% [markdown]
# ## Train a labeled LDA
#
# * tw=tp.TermWeight.ONE
# This sets the term weighting scheme to no weighting (i.e., each word has equal importance).
# Alternative values include:
#     * tp.TermWeight.PMI – Pointwise Mutual Information
#     * tp.TermWeight.IDF – Inverse Document Frequency
#     * tp.TermWeight.TFIDF – Term Frequency–Inverse Document Frequency
#
# * min_cf=3
# Minimum collection frequency: a token must appear in at least 3 documents to be included in the vocabulary.
# This filters out extremely rare words to reduce noise.
#
# * rm_top=5
# Removes the top 5 most frequent tokens from the vocabulary.
# These are typically very common terms (e.g. "data", "report") that add little semantic value for topic modeling.

# %%
# Crear modelo Labeled LDA
unique_labels = df["label"].unique().tolist()
model = tp.PLDAModel(tw=tp.TermWeight.ONE, min_cf=3, rm_top=5)

# Añadir documentos
for tokens, label in zip(df["tokens"], df["label"]):
    model.add_doc(tokens, labels=[label])

# Entrenar
model.train(0)
for i in range(100, 1000, 100):
    model.train(100)
    print(f"Log-likelihood: {model.ll_per_word:.4f}")
# Out:
# Log-likelihood: -6.3274
# Log-likelihood: -6.3267
# Log-likelihood: -6.3256
# Log-likelihood: -6.3268
# Log-likelihood: -6.3258
# Log-likelihood: -6.3258
# Log-likelihood: -6.3263
# Log-likelihood: -6.3264
# Log-likelihood: -6.3263

# %% [markdown]
# ## Evaluate the Model

# %%
# Ver las palabras más relevantes por categoría
for i, label in enumerate(unique_labels):
    print(f"Top words for label '{label}':")
    print(model.get_topic_words(i, top_n=10))
    print()
# Out:
# Top words for label 'executive':
# [('report', 0.04956256225705147), ('glossary', 0.04543578624725342), ('quest', 0.041309013962745667), ('main', 0.03305546194314957), ('fields', 0.028928689658641815), ('descriptions', 0.028928689658641815), ('tab', 0.028928689658641815), ('definitions', 0.024801915511488914), ('informative', 0.024801915511488914), ('kpi', 0.024801915511488914)]
#
# Top words for label 'functional':
# [('detail', 0.012081567198038101), ('evolution', 0.011578238569200039), ('data', 0.011578238569200039), ('table', 0.011410461738705635), ('kpis', 0.01057158038020134), ('total', 0.01057158038020134), ('month', 0.010236027650535107), ('tab', 0.010068251751363277), ('also', 0.010068251751363277), ('detailed', 0.009900474920868874)]
#
# Top words for label 'index':
# [('business', 0.024372220039367676), ('executive', 0.021123673766851425), ('kpis', 0.018687263131141663), ('hotel', 0.017875127494335175), ('budget', 0.01625085435807705), ('contains', 0.015438716858625412), ('report', 0.015438716858625412), ('summary', 0.015438716858625412), ('evolution', 0.01462658029049635), ('cost', 0.01462658029049635)]
#
# Top words for label 'informative':
# [('index', 0.1944556087255478), ('views', 0.17434297502040863), ('buttons', 0.16763876378536224), ('interactive', 0.16093455255031586), ('report', 0.04361088573932648), ('bu', 0.013441941700875759), ('sensitive', 0.010089836083352566), ('since', 0.010089836083352566), ('split', 0.010089836083352566), ('contains', 0.010089836083352566)]
#
# Top words for label 'master data':
# [('table', 0.1072193905711174), ('adhoc', 0.04024912789463997), ('data', 0.04024912789463997), ('kpis', 0.026855075731873512), ('criteria', 0.026855075731873512), ('user', 0.026855075731873512), ('dimensions', 0.026855075731873512), ('shows', 0.026855075731873512), ('dynamic', 0.026855075731873512), ('parameters', 0.026855075731873512)]
#
# Top words for label 'other':
# [('account', 0.052541930228471756), ('quest', 0.03943920508027077), ('master', 0.03943920508027077), ('data', 0.03943920508027077), ('hotel', 0.03943920508027077), ('per', 0.02633647806942463), ('user', 0.02633647806942463), ('set', 0.02633647806942463), ('targets', 0.02633647806942463), ('hotels', 0.02633647806942463)]
#
# Top words for label 'self-service':
# [('summary', 0.07442068308591843), ('hidden', 0.059566255658864975), ('tooltip', 0.059566255658864975), ('hotel', 0.044711824506521225), ('sent', 0.029857397079467773), ('table', 0.029857397079467773), ('specific', 0.029857397079467773), ('master', 0.029857397079467773), ('popup', 0.029857397079467773), ('mail', 0.029857397079467773)]

# %%
tokens = preprocess("summary hidden tooltip hotel sent")
#doc = model.make_doc(tokens)
doc = model.make_doc(tokens, labels=unique_labels) 
topic_dist, _ = model.infer(doc)
    
# Get most probable label
best_label = max(zip(unique_labels, topic_dist), key=lambda x: x[1])[0]
print(best_label)
# Out:
# self-service

# %% [markdown]
# ## Use the model

# %%
# Aplicar a vistas sin categoría
unlabeled_df = pd.read_excel("../raw/Reporting_Inventory.xlsx", sheet_name="Views")
unlabeled_df = unlabeled_df[unlabeled_df["Category"].isna() & unlabeled_df["Description"].notna()]
unlabeled_df["tokens"] = unlabeled_df["Description"].apply(preprocess)

unlabeled_df.head(2)
# Out:
#     ID Data Product                    Report Name Product Owner  \
# 182       RPPBI0034  Corporate Market Share - 2024  Raven Jordan
# 183       RPPBI0034  Corporate Market Share - 2024  Raven Jordan
#
#                 PBIX_File                  Report View  \
# 182  CharacterReport.pbix  STR Forecast Dashboard 2024
# 183  CharacterReport.pbix  STR Forecast Dashboard 2025
#
#                                            Description Category      Status  \
# 182  The reports sent by STR every 3 months with fo...      NaN  Productive
# 183  The reports sent by STR every 3 months with fo...      NaN  Productive
#
#     Rename        Dimensions                    KPIs           Other Terms  \
# 182    NaN  Cities available  Occupancy, ADR, RevPar  %Chg last 2 forecast
# 183    NaN  Cities available  Occupancy, ADR, RevPar  %Chg last 2 forecast
#
#                                                Filters  \
# 182  Forecast Month, Flag STR is Yes, Hotel_Name is...
# 183  Forecast Month, Flag STR is Yes, Hotel_Name is...
#
#                                            Tags    Priority  \
# 182  STR Forecast, Corporate Market Share, 2024  Priority 1
# 183  STR Forecast, Corporate Market Share, 2024  Priority 1
#
#                                                 tokens
# 182  [reports, sent, str, every, months, forecast, ...
# 183  [reports, sent, str, every, months, forecast, ...

# %%
# Predecir la categoría más probable
predictions = []
for tokens in unlabeled_df["tokens"]:
    doc = model.make_doc(tokens)
    topic_dist, _ = model.infer(doc)

    # Buscar la mejor etiqueta usando su probabilidad
    best_label = max(zip(unique_labels, topic_dist), key=lambda x: x[1])[0]
    predictions.append(best_label)

unlabeled_df["predicted_category"] = predictions
unlabeled_df.head(10)
# Out:
#     ID Data Product                    Report Name     Product Owner  \
# 182       RPPBI0034  Corporate Market Share - 2024      Raven Jordan
# 183       RPPBI0034  Corporate Market Share - 2024      Raven Jordan
# 259       RPPBI0150  Corporate Market Share - 2025  Matthew Callahan
# 320       RPPBI0173      Daily Revenue Report 2025        Tasha Hall
# 358       RPPBI0062          Price Competitiveness     Nicole Carter
# 362       RPPBI0062          Price Competitiveness     Nicole Carter
#
#                 PBIX_File                  Report View  \
# 182  CharacterReport.pbix  STR Forecast Dashboard 2024
# 183  CharacterReport.pbix  STR Forecast Dashboard 2025
# 259       SameReport.pbix  STR Forecast Dashboard 2025
# 320      AboutReport.pbix       Pick Up Channel Detail
# 358      AboutReport.pbix             Booking Criteria
# 362      AboutReport.pbix                       Page 1
#
#                                            Description Category      Status  \
# 182  The reports sent by STR every 3 months with fo...      NaN  Productive
# 183  The reports sent by STR every 3 months with fo...      NaN  Productive
# 259  The reports sent by STR every 3 months with fo...      NaN  Productive
# 320                                            DELETED      NaN         NaN
# 358  This view is exclusively for Booking.com,given...      NaN  Productive
# 362                                           internal      NaN    Internal
#
#     Rename                                  Dimensions  \
# 182    NaN                            Cities available
# 183    NaN                            Cities available
# 259    NaN                            Cities available
# 320    NaN                                         NaN
# 358    NaN  BU, Country, City, Hotel, Brand, META, OTA
# 362    NaN                                         NaN
#
#                        KPIs           Other Terms  \
# 182  Occupancy, ADR, RevPar  %Chg last 2 forecast
# 183  Occupancy, ADR, RevPar  %Chg last 2 forecast
# 259  Occupancy, ADR, RevPar  %Chg last 2 forecast
# 320                     NaN                   NaN
# 358                     NaN                   NaN
# 362                     NaN                   NaN
#
#                                                Filters  \
# 182  Forecast Month, Flag STR is Yes, Hotel_Name is...
# 183  Forecast Month, Flag STR is Yes, Hotel_Name is...
# 259  Forecast Month, Flag STR is Yes, Hotel_Name is...
# 320                                                NaN
# 358                                                NaN
# 362                                                NaN
#
#                                            Tags    Priority  \
# 182  STR Forecast, Corporate Market Share, 2024  Priority 1
# 183  STR Forecast, Corporate Market Share, 2024  Priority 1
# 259        STR Forecast, Corporate Market Share  Priority 1
# 320                                         NaN  Priority 1
# 358                                         NaN  Priority 1
# 362                                         NaN  Priority 1
#
#                                                 tokens predicted_category
# 182  [reports, sent, str, every, months, forecast, ...         functional
# 183  [reports, sent, str, every, months, forecast, ...         functional
# 259  [reports, sent, str, every, months, forecast, ...         functional
# 320                                          [deleted]         functional
# 358  [view, exclusively, bookingcomgiven, offensive...         functional
# 362                                         [internal]         functional
