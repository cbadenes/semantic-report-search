# %% [markdown]
# # Raw Data Exploration
#
# This notebook explores the original Excel data files to understand the structure and content of each sheet.
# We will analyze:
# - Structure (number of rows/columns)
# - Relevant columns per sheet
# - Sample content for entity detection or regular expression use

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl")
from pathlib import Path


# Load both Excel files from data/raw
reporting_path = Path("../raw/Reporting_Inventory.xlsx")
glossary_path = Path("../raw/Business_Glossary.xlsx")

reporting_data = pd.read_excel(reporting_path, sheet_name=None)
glossary_data = pd.read_excel(glossary_path, sheet_name=None)

# %% [markdown]
# ## Overview of Reporting Inventory Sheets

# %%
# Display full content in cells (not truncated)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 100)

# Summary of each sheet in the reporting inventory
reporting_summary = {
    sheet: {
        "rows": df.shape[0],
        "columns": df.shape[1],
        "columns_names": list(df.columns)
    }
    for sheet, df in reporting_data.items()
}
pd.DataFrame.from_dict(reporting_summary, orient='index')
# Out:
#                             rows  columns  \
# Reporting Glossary            32        4
# Reports                      309       31
# Views Glossary                17        4
# Views                       1486       15
# Areas, Departments & Teams    63        5
# LookUp                         7        3
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                              columns_names
# Reporting Glossary                                                                                                                                                                                                                                                                                                                                                                                        [Unnamed: 0, INDEX REPORTING INVENTORY , Unnamed: 2, Unnamed: 3]
# Reports                     [guid, ID Data Product, Name, Description, Type of data product, BI Portal Section, Area, Department, Team, Team Product Owner, Category according to use, Release date, Current version, Status, Closing date, Transferred to, Refresh frequency, Main Data Sources, Sensitivity, RLS, Type of RLS, GDPR, Technology, Support material, Product Owner, Data Owner, Data Steward, Access, Monthly Effort (h), PBIX_File, ID_Data_Product_Dupl]
# Views Glossary                                                                                                                                                                                                                                                                                                                                                                                                [Unnamed: 0, INDEX VIEWS INVENTORY , Unnamed: 2, Unnamed: 3]
# Views                                                                                                                                                                                                                                                                                                 [ID Data Product, Report Name, Product Owner, PBIX_File, Report View, Description, Category, Status, Rename, Dimensions, KPIs, Other Terms, Filters, Tags, Priority]
# Areas, Departments & Teams                                                                                                                                                                                                                                                                                                                                                                                         [Area, Deparment, Team, Department Leader, Team Leader]
# LookUp                                                                                                                                                                                                                                                                                                                                                                                                                          [Views Category, Unnamed: 1, Views Status]

# %% [markdown]
# ### Reports sheet

# %%
# Extract the 'Reports' sheet as a separate DataFrame
reports_df = reporting_data["Reports"]

# Display basic info
print(f"Total rows: {reports_df.shape[0]} | Total columns: {reports_df.shape[1]}")

# Show the first few rows
reports_df.head(2)
# Out:
# Total rows: 309 | Total columns: 31
#            guid ID Data Product                               Name  \
# 0  (ID Purview)       RPPBI0001  Laundry Cost Analysis Report 2024
# 1  (ID Purview)       RPPBI0002  Laundry Cost Analysis Report 2023
#
#                                                                                                                                                             Description  \
# 0  Report focused on the deep analysis of cost imputations from Laundry account, providing inisight analysis regarding material cost and cleaning activity performance.
# 1  Report focused on the deep analysis of cost imputations from Laundry account, providing inisight analysis regarding material cost and cleaning activity performance.
#
#   Type of data product                           BI Portal Section  \
# 0               Report  BI for Operations & Global Transformation;
# 1               Report  BI for Operations & Global Transformation;
#
#                                  Area  Department           Team  \
# 0  Operations & Global Transformation  Operations  Room Division
# 1  Operations & Global Transformation  Operations  Room Division
#
#                  Team Product Owner Category according to use Release date  \
# 0  Operational Excellence Analytics                 Operative   2024-03-10
# 1  Operational Excellence Analytics                 Operative   2024-03-10
#
#   Current version      Status Closing date Transferred to Refresh frequency  \
# 0            v2.0  Historical   2025-01-09            NaN           Monthly
# 1            v2.0  Historical   2024-03-10            NaN           Monthly
#
#                                  Main Data Sources    Sensitivity RLS  \
# 0  Google Cloud;SAP Business Objects;TMS;Server F;  Organization;  No
# 1  Google Cloud;SAP Business Objects;TMS;Server F;  Organization;  No
#
#   Type of RLS GDPR Technology                        Support material  \
# 0         NaN  NaN   Power BI  Contains: User Guide and Documentation
# 1         NaN  NaN   Power BI  Contains: User Guide and Documentation
#
#   Product Owner   Data Owner Data Steward     Access  Monthly Effort (h)  \
# 0  Kelly Hunter  Larry Moore          NaN  BI Portal                 0.0
# 1  Kelly Hunter  Larry Moore          NaN  BI Portal                 0.0
#
#            PBIX_File ID_Data_Product_Dupl
# 0  LetterReport.pbix            RPPBI0001
# 1     HotReport.pbix            RPPBI0002

# %%
# Extract the glossary sheet to map field descriptions
glossary_df = reporting_data["Reporting Glossary"]

# Build a dictionary of field -> description (cleaning columns)
glossary_df = glossary_df.rename(columns={
    glossary_df.columns[1]: "field",
    glossary_df.columns[2]: "description"
})
field_descriptions = glossary_df.set_index("field")["description"].to_dict()

# Build a diagnostic table
field_diagnostics = []

for col in reports_df.columns:
    col_data = reports_df[col]
    null_count = col_data.isnull().sum()
    unique_count = col_data.nunique(dropna=True)
    sample_values = col_data.dropna().astype(str).value_counts().head(5).to_dict()
    
    field_diagnostics.append({
        "field": col,
        "description": field_descriptions.get(col, "No description in glossary"),
        "null_count": null_count,
        "null_percentage": round(null_count / len(col_data) * 100, 2),
        "unique_values": unique_count,
        "top_5_values": sample_values
    })

# Convert to DataFrame for easy viewing
field_diagnostics_df = pd.DataFrame(field_diagnostics).sort_values(by="null_percentage", ascending=False)
field_diagnostics_df.reset_index(drop=True, inplace=True)

# Display the summary
field_diagnostics_df.head(32)
# Out:
#                         field  \
# 0                 Type of RLS
# 1              Transferred to
# 2                Data Steward
# 3                        GDPR
# 4            Support material
# 5                Closing date
# 6                  Data Owner
# 7                Release date
# 8          Monthly Effort (h)
# 9             Current version
# 10                Sensitivity
# 11          Main Data Sources
# 12                Description
# 13                     Access
# 14          Refresh frequency
# 15  Category according to use
# 16                        RLS
# 17         Team Product Owner
# 18                       Area
# 19                       Team
# 20                 Department
# 21          BI Portal Section
# 22              Product Owner
# 23                  PBIX_File
# 24                       guid
# 25                 Technology
# 26            ID Data Product
# 27                     Status
# 28       Type of data product
# 29                       Name
# 30       ID_Data_Product_Dupl
#
#                                                                                                                                                                                                                                                                                                                                                                                  description  \
# 0                                                                                                                                                                                                                                                                                                                                                       The type of RLS restriction applied.
# 1                                                                                                                                                                                                                                                                                                                                                                 No description in glossary
# 2   Member that acts as a Data Steward (with strong knowledge of how to apply business rules in reporting and ensure data quality). This could be an individual or group that defines the standards for the data catalog. A data steward is responsible for maintaining nomenclature, data quality standards, security controls, compliance requirements, and rules for the assigned object.
# 3                                                                                                                                                                                                                                                                                                                                                     Wether it contains GDPR sensitive data
# 4                                                                                                                                                                                                                                                                Localization of documentation for users, refreshment manual, technical documentation for BI to facilitate future handovers.
# 5                                                                                                                                                                                                                                                                                                                                                                 No description in glossary
# 6                                                                                                                                                                          Business member with extensive knowledge of the insights provided by the report. Owners are often senior executives or business area owners that define governance or business processes over certain data areas.
# 7                                                                                                                                                                                                                                                                                                                                                                 No description in glossary
# 8                                                                                                                                                                                                                                                                                                                Estimated manual effort (in hours) to update and validate the data product.
# 9                                                                                                                                                                                                                                                                                                                                                                 No description in glossary
# 10                                                                                                                                                                                                                                                                                                                                                           Data Products' scope and access
# 11                                                                                                                                                                                                                                                                                                                                                     Main Data Sources of the Data Product
# 12                                                                                                                                                                                                                                                                                                                                                     Brief description of the Data Product
# 13                                                                                                                                                                                                                                                                                                                                                               Access to the Data Product.
# 14                                                                                                                                                                                                                                                                                                          Frecuency in updating the information in a report or renewing/maintaining a tool
# 15                                                                                                                                                                                                                                                                                                                                                           Classification according to use
# 16                                                                                                                                                                                                                                                                                                Indicates whether the report has to apply or not any kind of access restriction using RLS.
# 17                                                                                                                                                                                                                                                                                                                                                    The team who develops the Data Product
# 18                                                                                                                                                                                                                                                                                                                                                                  Area of the organization
# 19                                                                                                                                                                                                                                                                                                                                                                Team within the department
# 20                                                                                                                                                                                                                                                                                                                                                                Department within the area
# 21                                                                                                                                                                                                                                                                                                                                                        Section of the BI Knowledge Portal
# 22                                                                                                                                                                                                               Member that acts as a Data Product Owner (responsible for managing/maintaining the product). Experts are often business experts in different business areas or departments.
# 23                                                                                                                                                                                                                                                                                                                       Name of the PBIX file (only for data products created in Power BI).
# 24                                                                                                                                                                                                                                                                                                                                                                No description in glossary
# 25                                                                                                                                                                                                                                                                                                                                                       Technology used in the Data Product
# 26                                                                                                                                                                                                                                                                                                                                                            Data Product identifier number
# 27                                                                                                                                                                                                                                                                                                                                                                 Stage of the Data Product
# 28                                                                                                                                                                                                                                                                                                                                                                      Type of Data Product
# 29                                                                                                                                                                                                                                                                                                                                                          Oficial name of the Data Product
# 30                                                                                                                                                                                                                                                                                                                                                                No description in glossary
#
#     null_count  null_percentage  unique_values  \
# 0          306            99.03              2
# 1          264            85.44             31
# 2          256            82.85             13
# 3          217            70.23              3
# 4          217            70.23              4
# 5          203            65.70             57
# 6          187            60.52             24
# 7          174            56.31             74
# 8          164            53.07             14
# 9           87            28.16             12
# 10          65            21.04              7
# 11          63            20.39             62
# 12          60            19.42            114
# 13          46            14.89              2
# 14          22             7.12             11
# 15          10             3.24              3
# 16           4             1.29              2
# 17           1             0.32              7
# 18           1             0.32              6
# 19           1             0.32             25
# 20           1             0.32             13
# 21           1             0.32             12
# 22           0             0.00             30
# 23           0             0.00            275
# 24           0             0.00              1
# 25           0             0.00              2
# 26           0             0.00            308
# 27           0             0.00              6
# 28           0             0.00              2
# 29           0             0.00            267
# 30           0             0.00            308
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      top_5_values
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     {'HQ-All, BU-All, HotelSpecific-Hotel, Other-None': 2, 'HQ-All, BU-All': 1}
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                {'RPPBI0142': 5, 'RPPBI0168': 4, 'RPPBI0122': 3, 'RPPBI0021': 2, 'RPPBI0133': 2}
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           {'Matthew Dennis': 16, 'Kelly Hunter': 7, 'Elizabeth Lynch': 6, 'Tasha Hall': 4, 'Tyler Stephens': 4}
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 {'No': 65, 'Yes': 26, 'YES': 1}
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             {'Contains: User Guide': 43, 'Contains: User Guide and Documentation': 32, 'Contains: Documentation': 14, 'Contains: Glossary for Certificates': 3}
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             {'2024-01-07 00:00:00': 19, '2025-01-07 00:00:00': 7, '2023-07-15 00:00:00': 5, '2025-01-01 00:00:00': 5, '2024-04-01 00:00:00': 4}
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     {'Jonathan Shields': 17, 'Larry Moore': 14, 'Ronald Cole': 14, 'Cynthia White': 12, 'Christopher Chung': 8}
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          {'2025-01-01': 17, '2023-01-01': 8, '2024-09-01': 6, '2024-01-01': 6, '2022-03-01': 4}
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        {'0.0': 34, '0.5': 25, '1.0': 23, '2.0': 20, '30.0': 13}
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     {'v1.0': 132, 'v2.0': 52, 'v3.0': 15, 'v4.0': 6, 'v2.1': 3}
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 {'Organization;': 202, 'Restricted': 29, 'HQ;': 6, 'Restricted;': 3, 'BU;': 2}
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                {'Google Cloud;': 48, 'Google Cloud;SAP Business Objects;TMS;Server F;': 17, 'Google Cloud; Server F': 14, 'Google Cloud': 12, 'Sharepoint': 8}
# 12  {'Where the business is coming from to my hotel and which are the main destinations where a Business Unit is sending business': 9, 'Report to track the usage of our reports in terms of users views, number of reports, pages...': 7, 'Report to follow up on the Managed Business performance at Portfolio level with maximum level of detail + C4C Activities.': 7, 'Report that would help us to analyze and understand the contracting season comparing the current performance vs last season and Contract information and production': 7, 'Report that would help us to analyze & understand the B2B Digital business performance': 7}
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 {'BI Portal': 195, 'Link': 68}
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        {'Monthly': 118, 'Weekly': 91, 'Daily': 31, 'Yearly': 14, 'Ad-Hoc': 12}
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     {'Operative': 196, 'Key': 96, 'Ad-Hoc': 7}
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          {'No': 296, 'Yes': 9}
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                {'Commercial & Marketing Analytics': 173, 'Operational Excellence Analytics': 100, 'Data Governance': 22, 'Internal Audit & Risk Management': 7, 'Compensation, Rewards & People Analytics': 3}
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      {'Commercial': 206, 'Operations & Global Transformation': 76, 'Marketing': 14, 'People & Sustainable Business': 8, 'Controlling & Strategic Planning': 2}
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             {'Revenue Management': 60, 'Business Development': 52, 'GEM': 38, 'Data Governance': 22, 'Business Processes': 20}
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     {'Sales & Distribution': 67, 'Revenue Strategy': 65, 'Operations': 46, 'Contact Centers': 43, 'Business Intelligence': 22}
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                     {'BI for Revenue Strategy;': 77, 'BI for Commercial;': 51, 'Not in BI Knowledge Portal': 50, 'BI for Operations & Global Transformation;': 42, 'BI for Commercial Groups [MICE-LGR];': 33}
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      {'Bradley Garcia': 33, 'Kelly Hunter': 30, 'Raven Jordan': 30, 'Jonathan Shields': 25, 'David Gomez': 25}
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       {'WorldReport.pbix': 3, 'MagazineReport.pbix': 3, 'LetterReport.pbix': 2, 'DefenseReport.pbix': 2, 'AreaReport.pbix': 2}
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          {'(ID Purview)': 309}
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 {'Power BI': 287, 'Excel': 22}
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               {'RPPBI0045': 2, 'RPPBI0001': 1, 'RPXLX0003': 1, 'RPPBI0211': 1, 'RPPBI0210': 1}
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 {'Historical': 127, 'Active': 119, 'Transferred': 46, 'In development': 10, 'Discontinued': 5}
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    {'Report': 281, 'Tool': 28}
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           {'Power BI Monitoring': 6, 'Budget 2025 Report': 5, 'Media Report': 4, 'Website Performance Report': 3, 'Weekly Activity - 2023': 3}
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               {'RPPBI0045': 2, 'RPPBI0001': 1, 'RPXLX0003': 1, 'RPPBI0211': 1, 'RPPBI0210': 1}

# %% [markdown]
# ### Views sheet

# %%
# Extract the 'Views' sheet as a separate DataFrame
views_df = reporting_data["Views"]

# Display basic info
print(f"Total rows: {views_df.shape[0]} | Total columns: {views_df.shape[1]}")

# Show the first few rows
views_df.head(2)
# Out:
# Total rows: 1486 | Total columns: 15
#   ID Data Product           Report Name     Product Owner        PBIX_File  \
# 0       RPPBI0032  Feeder Market - 2024  Jonathan Shields  LifeReport.pbix
# 1       RPPBI0032  Feeder Market - 2024  Jonathan Shields  LifeReport.pbix
#
#                      Report View  \
# 0                       CRITERIA
# 1  DESTINATION_OF_FEEDER_MARKETS
#
#                                                                                                         Description  \
# 0                                                     Methodolody and definition of the algorithim of Feeder Market
# 1  View focused on understand the performance by hotel for a specific feeder market o selection of feeder marktes.
#
#       Category      Status Rename  \
# 0  Informative  Productive    NaN
# 1   Functional  Productive    NaN
#
#                                                      Dimensions  \
# 0                                                           NaN
# 1  Hotel, month, Feeder Market, Segment, Channel Mix, Room Type
#
#                                                                                    KPIs  \
# 0                                                                                   NaN
# 1  Total Revenue, Room Revenue, RN, Lead Time, Lenght of Stay, AOV, ADR, ADR Net, %Cost
#
#   Other Terms Filters Tags    Priority
# 0         NaN     NaN  NaN  Priority 1
# 1         NaN     NaN  NaN  Priority 1

# %%
# Extract the glossary sheet for views
views_glossary_df = reporting_data["Views Glossary"]

# Clean and rename glossary columns to map field descriptions
views_glossary_df = views_glossary_df.rename(columns={
    views_glossary_df.columns[1]: "field",
    views_glossary_df.columns[2]: "description"
})
views_field_descriptions = views_glossary_df.set_index("field")["description"].to_dict()

# Build the diagnostic summary for Views
views_diagnostics = []

for col in views_df.columns:
    col_data = views_df[col]
    null_count = col_data.isnull().sum()
    unique_count = col_data.nunique(dropna=True)
    sample_values = col_data.dropna().astype(str).value_counts().head(5).to_dict()
    
    views_diagnostics.append({
        "field": col,
        "description": views_field_descriptions.get(col, "No description in glossary"),
        "null_count": null_count,
        "null_percentage": round(null_count / len(col_data) * 100, 2),
        "unique_values": unique_count,
        "top_5_values": sample_values
    })

# Convert to DataFrame and display
views_diagnostics_df = pd.DataFrame(views_diagnostics).sort_values(by="null_percentage", ascending=False)
views_diagnostics_df.reset_index(drop=True, inplace=True)

# Show the summary
views_diagnostics_df.head(20)
# Out:
#               field  \
# 0            Rename
# 1       Other Terms
# 2              Tags
# 3           Filters
# 4              KPIs
# 5        Dimensions
# 6            Status
# 7       Description
# 8          Category
# 9          Priority
# 10  ID Data Product
# 11      Report Name
# 12    Product Owner
# 13        PBIX_File
# 14      Report View
#
#                                                                                                                                                                     description  \
# 0                                                                                                                                                   New name of the Report View
# 1                                              List of other interesting terms such as specific and important values of dimensions, acronyms that offer extra information, etc.
# 2                                                                                                                                       Relevant keywords related to page view.
# 3                                                                                                                                           Filters applied at page view level.
# 4                                                                                                                                          List of main KPIs of the Report View
# 5                                                                                                                                    List of main dimensions of the Report View
# 6                                                                                                                                                     Stage of the Data Product
# 7                                                                                                                     Brief description of the Report View of the data product.
# 8                                                                                                                                                   Category of the Report View
# 9                                                                                                                            Priority to inventory and define the Reports View.
# 10                                                                                                                                               Data Product identifier number
# 11                                                                                                                                             Oficial name of the Data Product
# 12  Member that acts as a Data Product Owner (responsible for managing/maintaining the product). Experts are often business experts in different business areas or departments.
# 13                                                                                                          Name of the PBIX file (only for data products created in Power BI).
# 14                                                                                                                        Name of the Report View of the Power BI data product.
#
#     null_count  null_percentage  unique_values  \
# 0         1481            99.66              5
# 1         1367            91.99             51
# 2         1311            88.22             78
# 3         1277            85.94             32
# 4         1203            80.96            151
# 5         1191            80.15             97
# 6          975            65.61              4
# 7          922            62.05            379
# 8          505            33.98              7
# 9            2             0.13              7
# 10           0             0.00            238
# 11           0             0.00            206
# 12           0             0.00             30
# 13           0             0.00            224
# 14           0             0.00            758
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           top_5_values
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              {'Internal Surveys': 1, 'Executive Summary': 1, 'Online Ratings': 1, 'P&L Summary Tables': 1, 'Commercial Approach': 1}
# 1                                                                                                                                                                                                                                                                                                                                           {'eCommerce, OTA, Digital': 19, 'Actuals, Predicted;Forecast, TY, LY, LY2, NY': 8, 'Gross, FInancial, Net, Net Commercial, Fair': 7, 'CCG, CGW, CRO B2B Digital, NHPro Agencies, NHPro Companies, NHPro Meetings C&M, NHPro Meetings Form': 4, 'B2B Digital, Booking, CRO B2B Digital, CRO Web, Digital, eCommerce, Expedia, OTA, Web': 4}
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   {'Hotel Masterfile': 13, 'Benchmark, BPC, USALI, P&L': 11, 'OCI, Check-In': 8, 'Performance, eCommerce': 6, 'Performance, OTA': 5}
# 3                                                                                                                                                                                                                                                                                                                                                                        {'No': 83, 'Hotel_ID is not (blank)': 26, 'It has been excluded some hotels as: Casino de Madrid, BBVA, hotels from brasil...': 22, 'Hotel_Status_TY is OPEN': 11, 'BU & Sub BU; Month; Hotel; Contract & Consolidation; Country&City, Comparable; Contract; TOP GOP; Brand; RRM; DRM; RM;OpsRegional;RC': 7}
# 4                                                                                                                                                                                                                                                                                                                                                                                                                               {'Total Revenue, Room Revenue, RN, Lead Time, Lenght of Stay, AOV, ADR, ADR Net, %Cost': 11, 'EBITDA, GOP, Revenues, Expenses, BPC Accounts, Drivers, Totals, Ratios': 11, 'Total Revenue, Room Revenue, RN': 8, 'Total Revenue': 8, '% Occupancy': 8}
# 5   {'Hotel; Hotel_ID; Hotel_Brand; Hotel_BU; Hotel_SubBU; Hotel_Country; QUEST Scope; Operations Regional; Month; Hotel ID': 38, 'BU, Sub BU, Country, City, Name, Brand, Certification, OPS Regional, Comparable, Contract, Eng_MNT_Manager, Consolidation_Mngt': 27, 'Channel, Subchannel, BU, Country, Brand, Segment, Feeder Market, City, Hotel Name, Stay Month, Subsegment, Segment Type': 15, 'BU, Sub BU, Country, City, Name, Brand, OPS Regional, Comparable, Contract, Eng_MNT_Manager, Consolidation_Mngt, Consolidated': 9, 'Region, BU, SubBU, Country, City, Hotel, OPS Regional, Brand, Stars, Quality Team, Date, USALI, Department, Center of Cost, CECO, EFT': 9}
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                {'Productive': 427, 'Internal': 69, 'Discontinued': 10, 'Renamed': 5}
# 7                                                                                                                        {'Index page with interactive buttons to other views.': 43, 'Currently not in use. It remains as hiden until it's deleted permanently.': 6, 'Focus on Corporate Business (Corporate Sales & Airlines). Special focus on Account Segmentation.': 4, 'Index': 4, 'This view offers a vision of reservation behaviour, with focus on specific KPIs such that Lead Time, Lenght of Stay, AOV or Cancellation Rate. The KPIs can be analyzed by different dimensions, and also are shown in a dynamic table that allow users to select the dimensions needed.': 4}
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           {'Functional': 532, 'Index': 192, 'Executive': 130, 'Informative': 75, 'Self-Service': 25}
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      {'Priority 4': 391, 'Priority 1': 366, 'Priority 2': 299, 'Priority 3': 217, 'Priority 9': 204}
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              {'TLPBI0004': 47, 'RPPBI0137': 32, 'NOT MAPPED': 31, 'RPPBI0007': 28, 'RPPBI0016': 18}
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    {'Housekeeping In vs Out Advanced Tool': 47, 'Media Report': 35, 'QUESTforExcellence 2025': 32, 'NOT MAPPED': 31, 'QUESTforExcellence 2024': 28}
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       {'Kelly Hunter': 280, 'Bradley Garcia': 156, 'Raven Jordan': 118, 'David Gomez': 105, 'Matthew Callahan': 86}
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   {'LearnReport.pbix': 52, 'SeaReport.pbix': 44, 'CandidateReport.pbix': 28, 'SameReport.pbix': 22, 'EnvironmentalReport.pbix': 20}
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     {'Index': 124, 'Executive Summary': 30, 'MENU': 29, 'HOME': 24, 'Glossary': 18}

# %% [markdown]
# ### Export to CSV for API Use

# %%
# 1. Columns to include in the final DataFrame used by the API
output_columns = ["ID Data Product", "Report Name", "Report View","Tags"]

# 2. Columns used to generate the 'keywords' field
keyword_sources = ["Tags"]

# Load only the output columns initially
report_views_df = reporting_data["Views"][output_columns].copy()
report_views_df = report_views_df[report_views_df["ID Data Product"].notnull()]

# Access the full source sheet for additional keyword columns
full_views_df = reporting_data["Views"]

# Function to generate 'keywords' from selected source columns
def build_keywords(row_id):
    words = []
    row = full_views_df.loc[row_id]
    for col in keyword_sources:
        if col in row and pd.notna(row[col]):
            value = row[col]
            if col == "Tags":
                items = str(value).replace(";", ",").split(",")
            else:
                items = str(value).split()
            words.extend(item.strip() for item in items if len(item.strip()) > 2)
    return ", ".join(sorted(set(words)))

# Apply keyword generation using row index to access all columns
report_views_df["keywords"] = report_views_df.index.map(build_keywords)

# Display result
report_views_df.head(100)
# Out:
#    ID Data Product                Report Name  \
# 0        RPPBI0032       Feeder Market - 2024
# 1        RPPBI0032       Feeder Market - 2024
# 2        RPPBI0032       Feeder Market - 2024
# 3        RPPBI0032       Feeder Market - 2024
# 4        RPPBI0032       Feeder Market - 2024
# 5        RPPBI0032       Feeder Market - 2024
# 6        RPPBI0032       Feeder Market - 2024
# 7        RPPBI0032       Feeder Market - 2024
# 8        RPPBI0032       Feeder Market - 2024
# 9        RPPBI0154       Feeder Market - 2025
# 10       RPPBI0154       Feeder Market - 2025
# 11       RPPBI0154       Feeder Market - 2025
# 12       RPPBI0154       Feeder Market - 2025
# 13       RPPBI0154       Feeder Market - 2025
# 14       RPPBI0154       Feeder Market - 2025
# 15       RPPBI0154       Feeder Market - 2025
# 16       RPPBI0154       Feeder Market - 2025
# 17       RPPBI0154       Feeder Market - 2025
# 18       RPPBI0126     B2B Digital Sales 2025
# 19       RPPBI0126     B2B Digital Sales 2025
# 20       RPPBI0126     B2B Digital Sales 2025
# 21       RPPBI0126     B2B Digital Sales 2025
# 22       RPPBI0126     B2B Digital Sales 2025
# 23       RPPBI0143          Business Glossary
# 24       RPPBI0143          Business Glossary
# 25       RPPBI0143          Business Glossary
# 26       RPPBI0143          Business Glossary
# 27       RPPBI0143          Business Glossary
# 28       RPPBI0143          Business Glossary
# 29       RPPBI0143          Business Glossary
# 30       RPPBI0143          Business Glossary
# 31       RPPBI0143          Business Glossary
# 32       RPPBI0143          Business Glossary
# 33       RPPBI0143          Business Glossary
# 34       RPPBI0143          Business Glossary
# 35       RPPBI0143          Business Glossary
# 36       RPPBI0143          Business Glossary
# 37       RPPBI0143          Business Glossary
# 38       RPPBI0143          Business Glossary
# 39       RPPBI0004      eCommerce Report 2024
# 40       RPPBI0004      eCommerce Report 2024
# 41       RPPBI0004      eCommerce Report 2024
# 42       RPPBI0004      eCommerce Report 2024
# 43       RPPBI0004      eCommerce Report 2024
# 44       RPPBI0004      eCommerce Report 2024
# 45       RPPBI0004      eCommerce Report 2024
# 46       RPPBI0004      eCommerce Report 2024
# 47       RPPBI0004      eCommerce Report 2024
# 48       RPPBI0004      eCommerce Report 2024
# 49       RPPBI0004      eCommerce Report 2024
# 50       RPPBI0004      eCommerce Report 2024
# 51       RPPBI0004      eCommerce Report 2024
# 52       RPPBI0004      eCommerce Report 2024
# 53       RPPBI0004      eCommerce Report 2024
# 54       RPPBI0123      eCommerce Report 2025
# 55       RPPBI0123      eCommerce Report 2025
# 56       RPPBI0123      eCommerce Report 2025
# 57       RPPBI0123      eCommerce Report 2025
# 58       RPPBI0123      eCommerce Report 2025
# 59       RPPBI0123      eCommerce Report 2025
# 60       RPPBI0123      eCommerce Report 2025
# 61       RPPBI0123      eCommerce Report 2025
# 62       RPPBI0123      eCommerce Report 2025
# 63       RPPBI0123      eCommerce Report 2025
# 64       RPPBI0123      eCommerce Report 2025
# 65       RPPBI0123      eCommerce Report 2025
# 66       RPPBI0123      eCommerce Report 2025
# 67       RPPBI0123      eCommerce Report 2025
# 68       RPPBI0123      eCommerce Report 2025
# 69       RPPBI0123      eCommerce Report 2025
# 70       RPPBI0181       Direct Digital Sales
# 71       RPPBI0181       Direct Digital Sales
# 72       RPPBI0181       Direct Digital Sales
# 73       RPPBI0181       Direct Digital Sales
# 74       RPPBI0181       Direct Digital Sales
# 75       RPPBI0181       Direct Digital Sales
# 76       RPPBI0181       Direct Digital Sales
# 77       RPPBI0181       Direct Digital Sales
# 78       RPPBI0181       Direct Digital Sales
# 79       RPPBI0181       Direct Digital Sales
# 80       RPPBI0181       Direct Digital Sales
# 81       RPPBI0181       Direct Digital Sales
# 82       RPPBI0181       Direct Digital Sales
# 83       RPPBI0181       Direct Digital Sales
# 84       RPPBI0181       Direct Digital Sales
# 85       RPPBI0182  Direct Digital Sales 2024
# 86       RPPBI0182  Direct Digital Sales 2024
# 87       RPPBI0182  Direct Digital Sales 2024
# 88       RPPBI0182  Direct Digital Sales 2024
# 89       RPPBI0182  Direct Digital Sales 2024
# 90       RPPBI0182  Direct Digital Sales 2024
# 91       RPPBI0182  Direct Digital Sales 2024
# 92       RPPBI0182  Direct Digital Sales 2024
# 93       RPPBI0182  Direct Digital Sales 2024
# 94       RPPBI0182  Direct Digital Sales 2024
# 95       RPPBI0007    QUESTforExcellence 2024
# 96       RPPBI0007    QUESTforExcellence 2024
# 97       RPPBI0007    QUESTforExcellence 2024
# 98       RPPBI0007    QUESTforExcellence 2024
# 99       RPPBI0007    QUESTforExcellence 2024
#
#                                                     Report View  \
# 0                                                      CRITERIA
# 1                                 DESTINATION_OF_FEEDER_MARKETS
# 2                                                EXECUTIVE VIEW
# 3                                           FEEDER MARKET FLOWS
# 4                                          FEEDER_MARKET_DETAIL
# 5                                 FEEDER_MARKETS_OF_DESTINATION
# 6                                                          MENU
# 7                                            OE MARKET INSIGHTS
# 8                                             TARGETS FOLLOW UP
# 9                                                      CRITERIA
# 10                                DESTINATION_OF_FEEDER_MARKETS
# 11                                               EXECUTIVE VIEW
# 12                                          FEEDER MARKET FLOWS
# 13                                         FEEDER_MARKET_DETAIL
# 14                                FEEDER_MARKETS_OF_DESTINATION
# 15                                                         MENU
# 16                                           OE MARKET INSIGHTS
# 17                                            TARGETS FOLLOW UP
# 18                                                         MENU
# 19                                            SubChannel Detail
# 20                                             Web B2B Agencies
# 21                                            Web B2B Companies
# 22                                              WEB PERFORMANCE
# 23                                                   Commercial
# 24                              Controlling & StrategicPlanning
# 25                                Controlling&StrategicPlanning
# 26                                                  Data Office
# 27                                                      Datamap
# 28                                         DO_tentative_Datamap
# 29                                                          F&B
# 30                                                      Finance
# 31                                            General Secretary
# 32                                            Hierarchy_Datamap
# 33                                                        Index
# 34                                                    Main Page
# 35                                                       Manual
# 36                                                    Marketing
# 37                           Operations & Global Transformation
# 38                                 People & Sustainabe Business
# 39                                           B2B Digital Report
# 40                                             Database Browser
# 41                             Database Browser (Creation Date)
# 42                  Digital By Creation Date Performance Report
# 43                              Digital Performance (Stay Date)
# 44                 Ecommerce Performance (Creation Date) Report
# 45                                             Executive Report
# 46                                            Hotel View Report
# 47                                                        Index
# 48                                       Hotel Discovery Report
# 49                      OTAs Performance (Creation Date) Report
# 50                           OTAS Performance(Stay Date) Report
# 51                                           Performance Report
# 52                                Reservations Behaviour Report
# 53                                       Top Destination Report
# 54                                           B2B Digital Report
# 55                                             Database Browser
# 56                             Database Browser (Creation Date)
# 57                  Digital By Creation Date Performance Report
# 58                              Digital Performance (Stay Date)
# 59                 Ecommerce Performance (Creation Date) Report
# 60                                             Executive Report
# 61                                            Hotel View Report
# 62                                                        Index
# 63                                    REDACTED DISCOVERY Report
# 64                                       Hotel Discovery Report
# 65                      OTAs Performance (Creation Date) Report
# 66                           OTAS Performance(Stay Date) Report
# 67                                           Performance Report
# 68                                Reservations Behaviour Report
# 69                                       Top Destination Report
# 70                                                        INDEX
# 71                                          1.1.DISCOVERY SALES
# 72                                          1.EXECUTIVE SUMMARY
# 73                                                2.1.FC DETAIL
# 74                                  2.2 FC MODEL VS AUTO FC PWC
# 75                                          2.EFT FC BY CHANNEL
# 76                                       3.1.COMMERCIAL COST FC
# 77                                        3.2.FINANCIAL COST FC
# 78                               3.3.PATH FROM COMM TO FIN COST
# 79                                      3.4. HOTEL COSTS DETAIL
# 80                                         3.COMMISSION COST FC
# 81                                 4. FC EVOLUTION & ACCURACIES
# 82                          5. RAW DATA - DYNAMIC ANALYSIS TOOL
# 83                                           6.WEB MEDIA REPORT
# 84                                             CHANNEL GLOSSARY
# 85                                           % Channel Accuracy
# 86                                              % Cost Accuracy
# 87  COMMERCIAL (Check out) & FINANCIAL COST + Reversal + Ajuste
# 88                                     COMMERCIAL COST FORECAST
# 89                                              DISCOVERY SALES
# 90                                            Executive Summary
# 91                                              FORECAST DETAIL
# 92                                                        Index
# 93                              Revenue EFT Forecast by Channel
# 94                                         STEPS COST CHECK OUT
# 95                                                Cash Expenses
# 96                                                   Chargebks.
# 97                                                        Comm.
# 98                                                      Credits
# 99                                                 CXL / NoShow
#
#                       Tags                keywords
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29                     NaN
# 30                     NaN
# 31                     NaN
# 32                     NaN
# 33                     NaN
# 34                     NaN
# 35                     NaN
# 36                     NaN
# 37                     NaN
# 38                     NaN
# 39             B2B Digital             B2B Digital
# 40                     NaN
# 41                     NaN
# 42    Performance, Digital    Digital, Performance
# 43    Performance, Digital    Digital, Performance
# 44  Performance, eCommerce  Performance, eCommerce
# 45     Budget, Performance     Budget, Performance
# 46                   Hotel                   Hotel
# 47                     NaN
# 48      Discovery, Loyalty      Discovery, Loyalty
# 49        Performance, OTA        OTA, Performance
# 50        Performance, OTA        OTA, Performance
# 51  Performance, eCommerce  Performance, eCommerce
# 52   Reservation Behaviour   Reservation Behaviour
# 53                     NaN
# 54             B2B Digital             B2B Digital
# 55                     NaN
# 56                     NaN
# 57    Performance, Digital    Digital, Performance
# 58    Performance, Digital    Digital, Performance
# 59  Performance, eCommerce  Performance, eCommerce
# 60     Budget, Performance     Budget, Performance
# 61                   Hotel                   Hotel
# 62                     NaN
# 63      Discovery, Loyalty      Discovery, Loyalty
# 64      Discovery, Loyalty      Discovery, Loyalty
# 65        Performance, OTA        OTA, Performance
# 66        Performance, OTA        OTA, Performance
# 67  Performance, eCommerce  Performance, eCommerce
# 68   Reservation Behaviour   Reservation Behaviour
# 69                     NaN
# 70                     NaN
# 71                     NaN
# 72                     NaN
# 73                     NaN
# 74                     NaN
# 75                     NaN
# 76                     NaN
# 77                     NaN
# 78                     NaN
# 79                     NaN
# 80                     NaN
# 81                     NaN
# 82                     NaN
# 83                     NaN
# 84                     NaN
# 85                     NaN
# 86                     NaN
# 87                     NaN
# 88                     NaN
# 89                     NaN
# 90                     NaN
# 91                     NaN
# 92                     NaN
# 93                     NaN
# 94                     NaN
# 95                     NaN
# 96                     NaN
# 97                     NaN
# 98                     NaN
# 99                     NaN

# %%
from pathlib import Path

# Define the target path for the API data directory
api_output_path = Path("../api")
api_output_path.mkdir(parents=True, exist_ok=True)  # Create the folder if it doesn't exist

# Define the output CSV file path
csv_path = api_output_path / "reports.csv"

# Export the DataFrame to CSV (no index)
report_views_df.to_csv(csv_path, index=False)

print(f"CSV file saved at: {csv_path}")
# Out:
# CSV file saved at: ../api/reports.csv

# %% [markdown]
# ## Overview of Business Glossary Sheets

# %%
# Summary of each sheet in the business glossary
glossary_summary = {
    sheet: {
        "rows": df.shape[0],
        "columns": df.shape[1],
        "columns_names": list(df.columns)
    }
    for sheet, df in glossary_data.items()
}
pd.DataFrame.from_dict(glossary_summary, orient='index')
# Out:
#                   rows  columns  \
# Consolidated      1855       74
# Datamap            182        8
# Informed            35        3
# DataStewards        16        5
# DataOffice          23       19
# Controlling        898       19
# FB                  45       19
# GeneralSecretary     1       19
# Marketing           11       19
# Operations          28       19
# Finance             22       19
# Commercial         826       19
# Hoja1                0        0
# People               1       19
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   columns_names
# Consolidated      [Nick Name, Name, Definition, IsDefinitionRichText, Status, Related Terms, Synonyms, Acronym, Experts, Stewards, Resources, Parent Term Name, Term Template Names, [Attribute][Data Office template]Asset type, [Attribute][Data Office template]Calculation, [Attribute][Data Office template]Domain, [Attribute][Data Office template]GDPR, [Attribute][Data Office template]Scope, [Attribute][Data Office template]Subdomain, [Attribute][Controlling and Strategic Planning]Asset type, [Attribute][Controlling and Strategic Planning]Calculation, [Attribute][Controlling and Strategic Planning]Domain, [Attribute][Controlling and Strategic Planning]GDPR, [Attribute][Controlling and Strategic Planning]Scope, [Attribute][Controlling and Strategic Planning]Subdomain, [Attribute][FB template]Asset type, [Attribute][FB template]Calculation, [Attribute][FB template]Domain, [Attribute][FB template]GDPR, [Attribute][FB template]Scope, [Attribute][FB template]Subdomain, [Attribute][Finance template]Asset type, [Attribute][Finance template]Calculation, [Attribute][Finance template]Domain, [Attribute][Finance template]GDPR, [Attribute][Finance template]Scope, [Attribute][Finance template]Subdomain, [Attribute][General Secretary template]Asset type, [Attribute][General Secretary template]Calculation, [Attribute][General Secretary template]Domain, [Attribute][General Secretary template]GDPR, [Attribute][General Secretary template]Scope, [Attribute][General Secretary template]Subdomain, [Attribute][Marketing template]Asset type, [Attribute][Marketing template]Calculation, [Attribute][Marketing template]Domain, [Attribute][Marketing template]GDPR, [Attribute][Marketing template]Scope, [Attribute][Marketing template]Subdomain, [Attribute][Operations and Global Transformation]Asset type, [Attribute][Operations and Global Transformation]Calculation, [Attribute][Operations and Global Transformation]Domain, [Attribute][Operations and Global Transformation]GDPR, [Attribute][Operations and Global Transformation]Scope, [Attribute][Operations and Global Transformation]Subdomain, [Attribute][People and Sustainable Business template]Asset type, [Attribute][People and Sustainable Business template]Calculation, [Attribute][People and Sustainable Business template]Domain, [Attribute][People and Sustainable Business template]GDPR, [Attribute][People and Sustainable Business template]Scope, [Attribute][People and Sustainable Business template]Subdomain, [Attribute][Commercial template]Asset type, [Attribute][Commercial template]Calculation, [Attribute][Commercial template]Domain, [Attribute][Commercial template]GDPR, [Attribute][Commercial template]Scope, [Attribute][Commercial template]Subdomain, Area, Domain, Subdomain, GDPR, Calculation, Asset type, Data Owner]
# Datamap                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [Area, Domain, Subdomain, Name, Role, Experts, Tier, Informed]
# Informed                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [Name, Mail, Training]
# DataStewards                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [Subdomain, NameDS, RoleDS, Steward, InformedDS]
# DataOffice                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [Nick Name, Name, Definition, IsDefinitionRichText, Status, Related Terms, Synonyms, Acronym, Experts, Stewards, Resources, Parent Term Name, Term Template Names, [Attribute][Data Office template]Asset type, [Attribute][Data Office template]Calculation, [Attribute][Data Office template]Domain, [Attribute][Data Office template]GDPR, [Attribute][Data Office template]Scope, [Attribute][Data Office template]Subdomain]
# Controlling                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [Nick Name, Name, Definition, IsDefinitionRichText, Status, Related Terms, Synonyms, Acronym, Experts, Stewards, Resources, Parent Term Name, Term Template Names, [Attribute][Controlling and Strategic Planning]Asset type, [Attribute][Controlling and Strategic Planning]Calculation, [Attribute][Controlling and Strategic Planning]Domain, [Attribute][Controlling and Strategic Planning]GDPR, [Attribute][Controlling and Strategic Planning]Scope, [Attribute][Controlling and Strategic Planning]Subdomain]
# FB                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [Nick Name, Name, Definition, IsDefinitionRichText, Status, Related Terms, Synonyms, Acronym, Experts, Stewards, Resources, Parent Term Name, Term Template Names, [Attribute][FB template]Asset type, [Attribute][FB template]Calculation, [Attribute][FB template]Domain, [Attribute][FB template]GDPR, [Attribute][FB template]Scope, [Attribute][FB template]Subdomain]
# GeneralSecretary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [Nick Name, Name, Definition, IsDefinitionRichText, Status, Related Terms, Synonyms, Acronym, Experts, Stewards, Resources, Parent Term Name, Term Template Names, [Attribute][General Secretary template]Asset type, [Attribute][General Secretary template]Calculation, [Attribute][General Secretary template]Domain, [Attribute][General Secretary template]GDPR, [Attribute][General Secretary template]Scope, [Attribute][General Secretary template]Subdomain]
# Marketing                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [Nick Name, Name, Definition, IsDefinitionRichText, Status, Related Terms, Synonyms, Acronym, Experts, Stewards, Resources, Parent Term Name, Term Template Names, [Attribute][Marketing template]Asset type, [Attribute][Marketing template]Calculation, [Attribute][Marketing template]Domain, [Attribute][Marketing template]GDPR, [Attribute][Marketing template]Scope, [Attribute][Marketing template]Subdomain]
# Operations                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [Nick Name, Name, Definition, IsDefinitionRichText, Status, Related Terms, Synonyms, Acronym, Experts, Stewards, Resources, Parent Term Name, Term Template Names, [Attribute][Operations and Global Transformation]Asset type, [Attribute][Operations and Global Transformation]Calculation, [Attribute][Operations and Global Transformation]Domain, [Attribute][Operations and Global Transformation]GDPR, [Attribute][Operations and Global Transformation]Scope, [Attribute][Operations and Global Transformation]Subdomain]
# Finance                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [Nick Name, Name, Definition, IsDefinitionRichText, Status, Related Terms, Synonyms, Acronym, Experts, Stewards, Resources, Parent Term Name, Term Template Names, [Attribute][Finance template]Asset type, [Attribute][Finance template]Calculation, [Attribute][Finance template]Domain, [Attribute][Finance template]GDPR, [Attribute][Finance template]Scope, [Attribute][Finance template]Subdomain]
# Commercial                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [Nick Name, Name, Definition, IsDefinitionRichText, Status, Related Terms, Synonyms, Acronym, Experts, Stewards, Resources, Parent Term Name, Term Template Names, [Attribute][Commercial template]Asset type, [Attribute][Commercial template]Calculation, [Attribute][Commercial template]Domain, [Attribute][Commercial template]GDPR, [Attribute][Commercial template]Scope, [Attribute][Commercial template]Subdomain]
# Hoja1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        []
# People                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [Nick Name, Name, Definition, IsDefinitionRichText, Status, Related Terms, Synonyms, Acronym, Experts, Stewards, Resources, Parent Term Name, Term Template Names, [Attribute][People and Sustainable Business template]Asset type, [Attribute][People and Sustainable Business template]Calculation, [Attribute][People and Sustainable Business template]Domain, [Attribute][People and Sustainable Business template]GDPR, [Attribute][People and Sustainable Business template]Scope, [Attribute][People and Sustainable Business template]Subdomain]
